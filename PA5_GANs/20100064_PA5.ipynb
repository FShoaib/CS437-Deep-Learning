# %% [markdown]
# # Generative Adversarial Networks
# In this assignment, you’ll get hands-on experience coding and training GANs. This assignment is
# divided into two parts: in the first part, we will implement a specific type of GAN designed to
# process images, called a Deep Convolutional GAN (DCGAN). We’ll train the DCGAN to generate
# emojis from samples of random noise. In the second part, we will apply some methods that researchers have suggested to "stablize" the training process of GANs and then train our DCGAN again.
#
# **Note:** Please attempt this assignment on Google Colab, since that will speed up the training process.

# %%
# Uncomment and run these in Colab
# %tensorflow_version 1.x
# !pip install --upgrade opencv-python==3.4.2.17
import numpy as np
import tensorflow as tf
import keras
import keras.backend as K
from keras.layers import Conv2D,Activation,BatchNormalization,Conv2DTranspose, Input, Flatten, Dense, Reshape, LeakyReLU, Dropout
from keras.models import Sequential, Model
from keras.optimizers import Adam, SGD
import os
from glob import glob
from skimage.io import imread,imshow,imsave
from skimage.transform import resize
import matplotlib.pyplot as plt
import cv2
import math
from keras.preprocessing import image as k_image
from keras.utils.generic_utils import Progbar
from keras.initializers import RandomNormal
import random
# Out:
# TensorFlow 1.x selected.
# Collecting opencv-python==3.4.2.17
#   Downloading https://files.pythonhosted.org/packages/53/e0/21c8964fa8ef50842ebefaa7346a3cf0e37b56c8ecd97ed6bd2dbe577705/opencv_python-3.4.2.17-cp36-cp36m-manylinux1_x86_64.whl (25.0MB)
#      |████████████████████████████████| 25.0MB 1.3MB/s
# Requirement already satisfied, skipping upgrade: numpy>=1.11.3 in /usr/local/lib/python3.6/dist-packages (from opencv-python==3.4.2.17) (1.18.3)
# ERROR: albumentations 0.1.12 has requirement imgaug<0.2.7,>=0.2.5, but you'll have imgaug 0.2.9 which is incompatible.
# Installing collected packages: opencv-python
#   Found existing installation: opencv-python 4.1.2.30
#     Uninstalling opencv-python-4.1.2.30:
#       Successfully uninstalled opencv-python-4.1.2.30
# Successfully installed opencv-python-3.4.2.17
# Using TensorFlow backend.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
import shutil
import os
os.mkdir('DLAS5')
shutil.copy2('drive/My Drive/DLAS5/filtered_emojis.zip', 'DLAS5/filtered_emojis.zip')
# Out:
# 'DLAS5/filtered_emojis.zip'

# %%
# %cd ../content/DLAS5
#os.mkdir("full_emojis")
#%cd ./filtered_emojis
# !unzip 'filtered_emojis.zip'

# %%
ROLLNUMBER = 20100064
BATCH_SIZE = 128
IMAGE_SHAPE = [64,64]
CHANNELS = 3
NOISE_DIM = 100
EPOCHS = 2000
# Use this to prefix all your paths when reading/writing data to drive.
#BASE_DIR = ''
BASE_DIR = '/content/drive/My Drive/DLAS5'

# %% [markdown]
# - Here's the link to the emojis dataset: https://drive.google.com/open?id=1WRpE9SwSqguyGrrI9EP6jlHk7f1hoJMo
#
# - Here's the link to the full emojis dataset: https://drive.google.com/open?id=1UeIQIbixvapM-TBzngOwDXnHV_vv-MBG

# %% [markdown]
# ## PART 1: Deep Convolutional GAN (DCGAN)
# For the first part of this assignment, we will implement a Deep Convolutional GAN (DCGAN).
# A DCGAN is simply a GAN that uses a convolutional neural network as the discriminator, and
# a network composed of transposed convolutions as the generator. To implement the DCGAN, we
# need to specify three things: 1) the generator, 2) the discriminator, and 3) the training procedure.
# We will develop each of these three components in the following subsections.

# %%
## Helper Functions
def sample_noise():
    return np.reshape(np.random.randn(NOISE_DIM * BATCH_SIZE),(BATCH_SIZE,NOISE_DIM))

def remove_transparency(source, background_color):
    source_img = source[:, :, :3]
    source_mask = source[:, :, 3]  * (1 / 255.0)
    source_mask = np.repeat(source_mask[:, :, np.newaxis], 3, axis=2)
    background_mask = 1.0 - source_mask
    bg_part = (background_color * (1 / 255.0)) * (background_mask)
    source_part = (source_img * (1 / 255.0)) * (source_mask)
    return cv2.cvtColor(np.uint8(cv2.addWeighted(bg_part, 255.0, source_part, 255.0, 0.0)),cv2.COLOR_BGR2RGB)

def load_data():
    base_dir = 'filtered_emojis/*'
    train_files = glob(base_dir)
    train_images = np.array([cv2.resize(remove_transparency(cv2.imread(f,-1),255),tuple(IMAGE_SHAPE)) for f in train_files])
    return train_images

def create_image_grid(array, ncols=None):
    num_images, cell_h, cell_w, channels = array.shape
    if not ncols:
        ncols = int(np.sqrt(num_images))
    nrows = int(np.math.floor(num_images / float(ncols)))
    result = np.zeros((cell_h*nrows, cell_w*ncols, channels), dtype=array.dtype)
    for i in range(0, nrows):
        for j in range(0, ncols):
            result[i*cell_h:(i+1)*cell_h, j*cell_w:(j+1)*cell_w, :] = array[i*ncols+j]

    if channels == 1:
        result = result.squeeze()
    return result

# %% [markdown]
# ### Implementing the Discriminator of the DCGAN
# The discriminator in this DCGAN is a convolutional neural network that has the following architecture:
# <br>
# ![DCGAN Discriminator](DCGAN_disc.png)
# <br>

# %% [markdown]
# **Some Important points**:
# - Pass in the following arguments in your Convolutional Layers: padding='same',use_bias=False
# - After the last convolutional layer, Flatten the output and then add the final dense layer for prediction
# - Use kernel_size of (4,4), except the last one -- You may change this ((4,4) one) but don't reduce it too much
# - Reduce the spatial dimension by a factor of 2 after each convolution, except the last one.
# - Use LeakyRelu and BatchNormalization after each convolution

# %% [markdown]
# Implement the discriminator in the cell below:

# %%
def build_discriminator():
    input1 = Input(shape = (64,64,3))
    conv31 = Conv2D(64,(4,4),padding='same',strides=(2,2),use_bias=False)(input1)
    leaky1 = LeakyReLU(alpha = 0.3)(conv31)
    conv32 = Conv2D(128,(4,4),padding='same',strides=(2,2),use_bias=False)(leaky1)
    batch1 =  BatchNormalization()(conv32)
    leaky2 = LeakyReLU(alpha = 0.3)(batch1)
    conv33 = Conv2D(256,(4,4),padding='same',strides=(2,2),use_bias=False)(leaky2)
    batch2 =  BatchNormalization()(conv33)
    leaky3 = LeakyReLU(alpha = 0.3)(batch2)
    conv34 = Conv2D(512,(4,4),padding='same',strides=(2,2),use_bias=False)(leaky3)
    batch3 =  BatchNormalization()(conv34)
    leaky4 = LeakyReLU(alpha = 0.3)(batch3)
    conv35 = Conv2D(1,(2,2),padding='same',use_bias=False)(leaky3)
    flat1 = Flatten()(conv35)
    output = Dense(1,activation = 'sigmoid')(flat1)
    model_disc = Model(inputs=input1,outputs=output)

    adam = Adam(lr=0.0001)
    model_disc.compile(loss= 'binary_crossentropy',optimizer=adam, metrics=['accuracy'])

    return model_disc

# %% [markdown]
# ### Implementing the generator of DCGAN
# Now, we will implement the generator of the DCGAN, which consists of a sequence of transpose
# convolutional layers that progressively upsample the input noise sample to generate a fake image.
# The generator has the following architecture:
# <br>
# ![DCGAN Generator](DCGAN_gen.png)

# %% [markdown]
# **Some important points:**
# - Pass in use_bias=False,padding='same' in your convolutional layers.
# - All intermediate convolutional layers will have relu activation except the last one, which will have tanh.
# - All other properties can be inferred from the above diagram

# %% [markdown]
# Implement the generator in the cell below

# %%
def build_generator():
  input1 = Input(shape=(NOISE_DIM,))
  dense1 = Dense(4*4*1024)(input1)
  reshape = Reshape((4,4,1024))(dense1)
  tconv1 = Conv2DTranspose(512,(5,5),use_bias=False,padding='same',strides=(2,2),activation='relu')(reshape)
  batch1 = BatchNormalization()(tconv1)

  tconv2 = Conv2DTranspose(256,(5,5),use_bias=False,padding='same',strides=(2,2),activation='relu')(batch1)
  batch2 = BatchNormalization()(tconv2)

  tconv3 = Conv2DTranspose(128,(5,5),use_bias=False,padding='same',strides=(2,2),activation='relu')(batch2)
  batch3 = BatchNormalization()(tconv3)

  tconv4 = Conv2DTranspose(3,(5,5),use_bias=False,padding='same',strides=(2,2),activation='tanh')(batch3)
  
  model_gen = Model(inputs=input1,outputs=tconv4)
  adam = Adam(lr=0.0001)
  model_gen.compile(loss='categorical_crossentropy',optimizer=adam, metrics=['accuracy'])

  return model_gen

# %% [markdown]
# ### DCGAN Training Loop
# Next, you will implement the training loop for the DCGAN. A DCGAN is simply a GAN with a
# specific type of generator and discriminator; thus, we train it in exactly the same way as a standard
# GAN. The pseudo-code for the training procedure is shown below.

# %% [markdown]
# **Algorithm:**
# 1. Draw m training examples {x<sup>(1)</sup>,...,x<sup>(m)</sup>} from the data distribution p<sub>data</sub>.
# 2. Draw m noise samples {z<sup>(1)</sup>,...,z<sup>(m)</sup>} from the noise distribution p<sub>z</sub>.
# 3. Generate fake images from the noise: G(z<sup>(i)</sup>) for i in {1,....,m}.
# 4. Compute discriminator's loss on real images and fake images batches and then update the parameters.
# 5. Draw m NEW noise samples {z<sup>(1)</sup>,...,z<sup>(m)</sup>} from the noise distribution p<sub>z</sub>.
# 6. Generate fake images from the noise: G(z<sup>(i)</sup>) for i in {1,....,m}.
# 7. Freeze the discriminator.
# 8. Compute generator's loss then update the parameters.
# 9. Unfreeze the discriminator.

# %% [markdown]
# Before we move to writing the training loop, we will need to create a "combined" model that will attach the discriminator over the generator. This model will be used to train the generator as the discriminator will act as an adversary for the generator and force it to generate realistic images.

# %% [markdown]
# In this function below you need to create a model that:
# - Takes noise z as input (Matching the noise dimensions defined at the top of the notebook)
# - Gets a fake image generated from the generator using this noise z
# - "Freezes" the discriminator (Setting all layers of the discriminator as untrainable)
# - Outputs the output of the discriminator based on the input z.
#
# Remember to compile the model before returning it.

# %%
def build_gan(gen,disc):
  input1 = Input(shape = (NOISE_DIM,))
  img = gen(input1)

  for l in disc.layers:
    l.trainable = False;

  output1 = disc(img)
  model_dcgan = Model(inputs=input1,outputs=output1)

  model_dcgan.compile(loss='binary_crossentropy',optimizer= Adam(lr=0.001), metrics=['accuracy'])
  return model_dcgan

# %% [markdown]
# Write your training loop in the cell bellow. Some important points to keep in mind:
# - You need to compile the discriminator after creating an instance using build_discriminator()
# - Use the provided load_data() function to well... load the data. You can choose between generating Windows or Apple emojis
# - The entire data will be loaded as it is small enough to fit into memory (Finally no data generators, right?) BUT you still need to loop over the data in batches. Starter code is provided to you.
# - To train your models, we won't make use of <code>fit</code> instead we will use <code>train_on_batch</code> to train our model over batches. This method will return your model's loss over a particular batch, which you will use to output and store your history of losses.
# - Additionally, we will be generating samples after some epochs and storing the result on disk. The code is provided to do this.

# %%
def save_samples(generated_images,step,save_at="samples1/"):
    sample_image = create_image_grid(generated_images)
    img = k_image.array_to_img(sample_image)
    img.save(os.path.join(BASE_DIR,save_at, 'generated_image_' + str(step) + '.png'))

# %%
def gan_training_loop(intervals=200):
    # Setup Models here
    discriminator = build_discriminator()
    generator = build_generator()
    dcgan = build_gan(generator,discriminator)

    X_train = load_data()
    total_size = X_train.shape[0]
    indices = np.arange(0,total_size ,BATCH_SIZE)
    all_disc_loss = []
    all_gen_loss = []
    if total_size % BATCH_SIZE:
        indices = indices[:-1]
    for e in range(EPOCHS):
        progress_bar = Progbar(target=len(indices))
        np.random.shuffle(indices)
        epoch_gen_loss = []
        epoch_disc_loss = []
        for i,index in enumerate(indices):
            # Write your code here
            training_samples = X_train[index:index+BATCH_SIZE]
            noise_samples  = sample_noise()
              #generate imgs and
            generated_imgs = generator.predict(noise_samples)

            labels_real = np.ones((BATCH_SIZE,), dtype=int)
            labels_fake = np.zeros((BATCH_SIZE,), dtype=int)
            hist_disc_real = discriminator.train_on_batch(training_samples,labels_real)
            hist_disc_fake = discriminator.train_on_batch(generated_imgs,labels_fake)

            if not (e % intervals):
                save_samples(generated_imgs,e,save_at='samples_uns')     
            
            disc_loss = (hist_disc_real[0] + hist_disc_fake) * 0.5
            epoch_disc_loss.append(disc_loss)
            
            # Before training your generator using the combined model, freeze all layers of the discriminator first.
            # Unfreeze after your call to train_on_batch
            for l in discriminator.layers:
              l.trainable = False

            noise_gen = sample_noise()
            labels_gen = np.ones((BATCH_SIZE,), dtype=int)
            hist_gen = dcgan.train_on_batch(noise_gen,labels_gen)

            for l in discriminator.layers:
              l.trainable = True
      
            gen_loss = hist_gen[0]
            epoch_gen_loss.append(gen_loss)
            progress_bar.update(i+1)
        if not (e%intervals):
            # Save weights here
            discriminator.save_weights(os.path.join(BASE_DIR,'discriminator_uns'),True)
            generator.save_weights(os.path.join(BASE_DIR,'generator_uns'),True)

        avg_epoch_disc_loss = np.array(epoch_disc_loss).mean()
        avg_epoch_gen_loss = np.array(epoch_gen_loss).mean()
        all_disc_loss.append(avg_epoch_disc_loss)
        all_gen_loss.append(avg_epoch_gen_loss)

        print("Epoch: %d | Discriminator Loss: %f | Generator Loss: %f" % (e+1,avg_epoch_disc_loss,avg_epoch_gen_loss))
    return all_disc_loss,all_gen_loss

# %% [markdown]
# ### Training the GAN
# We will train a DCGAN to generate fake Apple emojis. 1 epoch should take about 15 seconds on Google Colab.

# %% [markdown]
# Train your DCGAN in the below cell

# %%
# %pwd
# Out:
# '/content/DLAS5'

# %%
all_disc_loss,all_gen_loss = gan_training_loop()
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
# /usr/local/lib/python3.6/dist-packages/keras/engine/training.py:297: UserWarning: Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
#   'Discrepancy between trainable weights and collected trainable'
# /usr/local/lib/python3.6/dist-packages/keras/engine/training.py:297: UserWarning: Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
#   'Discrepancy between trainable weights and collected trainable'
# 5/5 [==============================] - 13s 3s/step
# Epoch: 1 | Discriminator Loss: 0.427959 | Generator Loss: 0.275749
# 5/5 [==============================] - 2s 462ms/step
# Epoch: 2 | Discriminator Loss: 0.310509 | Generator Loss: 0.003468
# 5/5 [==============================] - 2s 467ms/step
# Epoch: 3 | Discriminator Loss: 0.253819 | Generator Loss: 0.007104
# 5/5 [==============================] - 2s 459ms/step
# Epoch: 4 | Discriminator Loss: 0.250140 | Generator Loss: 0.004723
# 5/5 [==============================] - 2s 465ms/step
# Epoch: 5 | Discriminator Loss: 0.250091 | Generator Loss: 0.001790
# 5/5 [==============================] - 2s 464ms/step
# Epoch: 6 | Discriminator Loss: 0.250101 | Generator Loss: 0.000424
# 5/5 [==============================] - 2s 467ms/step
# Epoch: 7 | Discriminator Loss: 0.250136 | Generator Loss: 0.000191
# 5/5 [==============================] - 2s 469ms/step
# Epoch: 8 | Discriminator Loss: 0.250184 | Generator Loss: 0.000122
# 5/5 [==============================] - 2s 469ms/step
# Epoch: 9 | Discriminator Loss: 0.250217 | Generator Loss: 0.000073
# 5/5 [==============================] - 2s 471ms/step
# Epoch: 10 | Discriminator Loss: 0.250213 | Generator Loss: 0.000089
# 5/5 [==============================] - 2s 468ms/step
# Epoch: 11 | Discriminator Loss: 0.250180 | Generator Loss: 0.000069
# 5/5 [==============================] - 2s 473ms/step
# Epoch: 12 | Discriminator Loss: 0.250149 | Generator Loss: 0.000064
# 5/5 [==============================] - 2s 472ms/step
# Epoch: 13 | Discriminator Loss: 0.250123 | Generator Loss: 0.000058
# 5/5 [==============================] - 2s 470ms/step
# Epoch: 14 | Discriminator Loss: 0.250107 | Generator Loss: 0.000073
# 5/5 [==============================] - 2s 470ms/step
# Epoch: 15 | Discriminator Loss: 0.250104 | Generator Loss: 0.000085
# 5/5 [==============================] - 2s 472ms/step
# Epoch: 16 | Discriminator Loss: 0.250095 | Generator Loss: 0.000073
# 5/5 [==============================] - 2s 471ms/step
# Epoch: 17 | Discriminator Loss: 0.250095 | Generator Loss: 0.000096
# 5/5 [==============================] - 2s 481ms/step
# Epoch: 18 | Discriminator Loss: 0.250088 | Generator Loss: 0.000068
# 5/5 [==============================] - 2s 482ms/step
# Epoch: 19 | Discriminator Loss: 0.250086 | Generator Loss: 0.000062
# 5/5 [==============================] - 2s 475ms/step
# Epoch: 20 | Discriminator Loss: 0.250084 | Generator Loss: 0.000065
# 5/5 [==============================] - 2s 476ms/step
# Epoch: 21 | Discriminator Loss: 0.250083 | Generator Loss: 0.000067
# 5/5 [==============================] - 2s 482ms/step
# Epoch: 22 | Discriminator Loss: 0.250083 | Generator Loss: 0.000071
# 5/5 [==============================] - 2s 481ms/step
# Epoch: 23 | Discriminator Loss: 0.250076 | Generator Loss: 0.000074
# 5/5 [==============================] - 2s 480ms/step
# Epoch: 24 | Discriminator Loss: 0.250075 | Generator Loss: 0.000072
# 5/5 [==============================] - 2s 485ms/step
# Epoch: 25 | Discriminator Loss: 0.250074 | Generator Loss: 0.000072
# 5/5 [==============================] - 2s 482ms/step
# Epoch: 26 | Discriminator Loss: 0.250072 | Generator Loss: 0.000068
# 5/5 [==============================] - 2s 482ms/step
# Epoch: 27 | Discriminator Loss: 0.250071 | Generator Loss: 0.000064
# 5/5 [==============================] - 2s 485ms/step
# Epoch: 28 | Discriminator Loss: 0.250071 | Generator Loss: 0.000060
# 5/5 [==============================] - 2s 481ms/step
# Epoch: 29 | Discriminator Loss: 0.250067 | Generator Loss: 0.000073
# 5/5 [==============================] - 2s 487ms/step
# Epoch: 30 | Discriminator Loss: 0.250068 | Generator Loss: 0.000072
# 5/5 [==============================] - 2s 485ms/step
# Epoch: 31 | Discriminator Loss: 0.250064 | Generator Loss: 0.000070
# 5/5 [==============================] - 2s 488ms/step
# Epoch: 32 | Discriminator Loss: 0.250066 | Generator Loss: 0.000072
# 5/5 [==============================] - 2s 484ms/step
# Epoch: 33 | Discriminator Loss: 0.250063 | Generator Loss: 0.000063
# 5/5 [==============================] - 2s 490ms/step
# Epoch: 34 | Discriminator Loss: 0.250060 | Generator Loss: 0.000067
# 5/5 [==============================] - 2s 485ms/step
# Epoch: 35 | Discriminator Loss: 0.250062 | Generator Loss: 0.000068
# 5/5 [==============================] - 2s 485ms/step
# Epoch: 36 | Discriminator Loss: 0.250062 | Generator Loss: 0.000067
# 5/5 [==============================] - 2s 485ms/step
# Epoch: 37 | Discriminator Loss: 0.250061 | Generator Loss: 0.000075
# 5/5 [==============================] - 2s 485ms/step
# Epoch: 38 | Discriminator Loss: 0.250058 | Generator Loss: 0.000080
# 5/5 [==============================] - 2s 490ms/step
# Epoch: 39 | Discriminator Loss: 0.250064 | Generator Loss: 0.000077
# 5/5 [==============================] - 2s 493ms/step
# Epoch: 40 | Discriminator Loss: 0.250059 | Generator Loss: 0.000065
# 5/5 [==============================] - 2s 485ms/step
# Epoch: 41 | Discriminator Loss: 0.250058 | Generator Loss: 0.000065
# 5/5 [==============================] - 2s 495ms/step
# Epoch: 42 | Discriminator Loss: 0.250056 | Generator Loss: 0.000081
# 5/5 [==============================] - 2s 483ms/step
# Epoch: 43 | Discriminator Loss: 0.250057 | Generator Loss: 0.000085
# 5/5 [==============================] - 2s 493ms/step
# Epoch: 44 | Discriminator Loss: 0.250055 | Generator Loss: 0.000076
# 5/5 [==============================] - 2s 483ms/step
# Epoch: 45 | Discriminator Loss: 0.250057 | Generator Loss: 0.000075
# 5/5 [==============================] - 2s 492ms/step
# Epoch: 46 | Discriminator Loss: 0.250058 | Generator Loss: 0.000074
# 5/5 [==============================] - 2s 486ms/step
# Epoch: 47 | Discriminator Loss: 0.250057 | Generator Loss: 0.000083
# 5/5 [==============================] - 2s 492ms/step
# Epoch: 48 | Discriminator Loss: 0.250058 | Generator Loss: 0.000087
# 5/5 [==============================] - 2s 488ms/step
# Epoch: 49 | Discriminator Loss: 0.250056 | Generator Loss: 0.000089
# 5/5 [==============================] - 2s 493ms/step
# Epoch: 50 | Discriminator Loss: 0.250058 | Generator Loss: 0.000078
# 5/5 [==============================] - 2s 493ms/step
# Epoch: 51 | Discriminator Loss: 0.250055 | Generator Loss: 0.000087
# 5/5 [==============================] - 2s 488ms/step
# Epoch: 52 | Discriminator Loss: 0.250056 | Generator Loss: 0.000084
# 5/5 [==============================] - 2s 493ms/step
# Epoch: 53 | Discriminator Loss: 0.250057 | Generator Loss: 0.000100
# 5/5 [==============================] - 2s 488ms/step
# Epoch: 54 | Discriminator Loss: 0.250054 | Generator Loss: 0.000099
# 5/5 [==============================] - 2s 491ms/step
# Epoch: 55 | Discriminator Loss: 0.250058 | Generator Loss: 0.000090
# 5/5 [==============================] - 2s 499ms/step
# Epoch: 56 | Discriminator Loss: 0.250057 | Generator Loss: 0.000094
# 5/5 [==============================] - 2s 493ms/step
# Epoch: 57 | Discriminator Loss: 0.250056 | Generator Loss: 0.000097
# 5/5 [==============================] - 2s 491ms/step
# Epoch: 58 | Discriminator Loss: 0.250061 | Generator Loss: 0.000104
# 5/5 [==============================] - 2s 495ms/step
# Epoch: 59 | Discriminator Loss: 0.250056 | Generator Loss: 0.000119
# 5/5 [==============================] - 2s 489ms/step
# Epoch: 60 | Discriminator Loss: 0.250062 | Generator Loss: 0.000116
# 5/5 [==============================] - 2s 495ms/step
# Epoch: 61 | Discriminator Loss: 0.250060 | Generator Loss: 0.000111
# 5/5 [==============================] - 2s 492ms/step
# Epoch: 62 | Discriminator Loss: 0.250056 | Generator Loss: 0.000116
# 5/5 [==============================] - 2s 495ms/step
# Epoch: 63 | Discriminator Loss: 0.250056 | Generator Loss: 0.000121
# 5/5 [==============================] - 2s 497ms/step
# Epoch: 64 | Discriminator Loss: 0.250061 | Generator Loss: 0.000118
# 5/5 [==============================] - 2s 490ms/step
# Epoch: 65 | Discriminator Loss: 0.250065 | Generator Loss: 0.000106
# 5/5 [==============================] - 2s 499ms/step
# Epoch: 66 | Discriminator Loss: 0.250063 | Generator Loss: 0.000122
# 5/5 [==============================] - 2s 498ms/step
# Epoch: 67 | Discriminator Loss: 0.250064 | Generator Loss: 0.000133
# 5/5 [==============================] - 2s 494ms/step
# Epoch: 68 | Discriminator Loss: 0.250060 | Generator Loss: 0.000133
# 5/5 [==============================] - 3s 501ms/step
# Epoch: 69 | Discriminator Loss: 0.250062 | Generator Loss: 0.000145
# 5/5 [==============================] - 3s 500ms/step
# Epoch: 70 | Discriminator Loss: 0.250071 | Generator Loss: 0.000127
# 5/5 [==============================] - 3s 504ms/step
# Epoch: 71 | Discriminator Loss: 0.250071 | Generator Loss: 0.000146
# 5/5 [==============================] - 3s 508ms/step
# Epoch: 72 | Discriminator Loss: 0.250067 | Generator Loss: 0.000159
# 5/5 [==============================] - 3s 503ms/step
# Epoch: 73 | Discriminator Loss: 0.250063 | Generator Loss: 0.000145
# 5/5 [==============================] - 2s 496ms/step
# Epoch: 74 | Discriminator Loss: 0.250070 | Generator Loss: 0.000143
# 5/5 [==============================] - 3s 501ms/step
# Epoch: 75 | Discriminator Loss: 0.250071 | Generator Loss: 0.000161
# 5/5 [==============================] - 3s 503ms/step
# Epoch: 76 | Discriminator Loss: 0.250080 | Generator Loss: 0.000170
# 5/5 [==============================] - 3s 506ms/step
# Epoch: 77 | Discriminator Loss: 0.250073 | Generator Loss: 0.000183
# 5/5 [==============================] - 3s 505ms/step
# Epoch: 78 | Discriminator Loss: 0.250080 | Generator Loss: 0.000188
# 5/5 [==============================] - 3s 508ms/step
# Epoch: 79 | Discriminator Loss: 0.250080 | Generator Loss: 0.000197
# 5/5 [==============================] - 3s 508ms/step
# Epoch: 80 | Discriminator Loss: 0.250086 | Generator Loss: 0.000185
# 5/5 [==============================] - 3s 506ms/step
# Epoch: 81 | Discriminator Loss: 0.250091 | Generator Loss: 0.000187
# 5/5 [==============================] - 3s 506ms/step
# Epoch: 82 | Discriminator Loss: 0.250097 | Generator Loss: 0.000213
# 5/5 [==============================] - 3s 510ms/step
# Epoch: 83 | Discriminator Loss: 0.250100 | Generator Loss: 0.000209
# 5/5 [==============================] - 3s 508ms/step
# Epoch: 84 | Discriminator Loss: 0.250087 | Generator Loss: 0.000241
# 5/5 [==============================] - 3s 506ms/step
# Epoch: 85 | Discriminator Loss: 0.250114 | Generator Loss: 0.000244
# 5/5 [==============================] - 3s 509ms/step
# Epoch: 86 | Discriminator Loss: 0.250095 | Generator Loss: 0.000276
# 5/5 [==============================] - 3s 508ms/step
# Epoch: 87 | Discriminator Loss: 0.250131 | Generator Loss: 0.000276
# 5/5 [==============================] - 3s 507ms/step
# Epoch: 88 | Discriminator Loss: 0.250118 | Generator Loss: 0.000303
# 5/5 [==============================] - 3s 508ms/step
# Epoch: 89 | Discriminator Loss: 0.250121 | Generator Loss: 0.000307
# 5/5 [==============================] - 3s 506ms/step
# Epoch: 90 | Discriminator Loss: 0.250150 | Generator Loss: 0.000311
# 5/5 [==============================] - 3s 506ms/step
# Epoch: 91 | Discriminator Loss: 0.250141 | Generator Loss: 0.000393
# 5/5 [==============================] - 3s 506ms/step
# Epoch: 92 | Discriminator Loss: 0.250157 | Generator Loss: 0.000385
# 5/5 [==============================] - 3s 503ms/step
# Epoch: 93 | Discriminator Loss: 0.250185 | Generator Loss: 0.000396
# 5/5 [==============================] - 3s 504ms/step
# Epoch: 94 | Discriminator Loss: 0.250184 | Generator Loss: 0.000448
# 5/5 [==============================] - 3s 505ms/step
# Epoch: 95 | Discriminator Loss: 0.250194 | Generator Loss: 0.000554
# 5/5 [==============================] - 2s 494ms/step
# Epoch: 96 | Discriminator Loss: 0.250263 | Generator Loss: 0.000445
# 5/5 [==============================] - 3s 501ms/step
# Epoch: 97 | Discriminator Loss: 0.250235 | Generator Loss: 0.000698
# 5/5 [==============================] - 3s 502ms/step
# Epoch: 98 | Discriminator Loss: 0.250318 | Generator Loss: 0.000663
# 5/5 [==============================] - 3s 505ms/step
# Epoch: 99 | Discriminator Loss: 0.250329 | Generator Loss: 0.000832
# 5/5 [==============================] - 3s 504ms/step
# Epoch: 100 | Discriminator Loss: 0.250441 | Generator Loss: 0.001115
# 5/5 [==============================] - 3s 505ms/step
# Epoch: 101 | Discriminator Loss: 0.250575 | Generator Loss: 0.001666
# 5/5 [==============================] - 2s 497ms/step
# Epoch: 102 | Discriminator Loss: 0.250880 | Generator Loss: 0.003265
# 5/5 [==============================] - 2s 498ms/step
# Epoch: 103 | Discriminator Loss: 0.254138 | Generator Loss: 0.053440
# 5/5 [==============================] - 3s 505ms/step
# Epoch: 104 | Discriminator Loss: 0.611239 | Generator Loss: 5.455465
# 5/5 [==============================] - 3s 504ms/step
# Epoch: 105 | Discriminator Loss: 2.141100 | Generator Loss: 6.800404
# 5/5 [==============================] - 3s 505ms/step
# Epoch: 106 | Discriminator Loss: 2.768008 | Generator Loss: 4.326484
# 5/5 [==============================] - 3s 505ms/step
# Epoch: 107 | Discriminator Loss: 2.119938 | Generator Loss: 3.597865
# 5/5 [==============================] - 3s 506ms/step
# Epoch: 108 | Discriminator Loss: 1.718468 | Generator Loss: 2.884436
# 5/5 [==============================] - 3s 503ms/step
# Epoch: 109 | Discriminator Loss: 1.517393 | Generator Loss: 1.826903
# 5/5 [==============================] - 3s 507ms/step
# Epoch: 110 | Discriminator Loss: 1.004974 | Generator Loss: 2.077009
# 5/5 [==============================] - 3s 507ms/step
# Epoch: 111 | Discriminator Loss: 0.993106 | Generator Loss: 1.900549
# 5/5 [==============================] - 3s 506ms/step
# Epoch: 112 | Discriminator Loss: 0.751836 | Generator Loss: 1.549544
# 5/5 [==============================] - 3s 508ms/step
# Epoch: 113 | Discriminator Loss: 0.609036 | Generator Loss: 1.769279
# 5/5 [==============================] - 3s 506ms/step
# Epoch: 114 | Discriminator Loss: 0.544466 | Generator Loss: 1.560016
# 5/5 [==============================] - 3s 506ms/step
# Epoch: 115 | Discriminator Loss: 0.452902 | Generator Loss: 1.758642
# 5/5 [==============================] - 3s 512ms/step
# Epoch: 116 | Discriminator Loss: 0.424733 | Generator Loss: 1.766604
# 5/5 [==============================] - 3s 509ms/step
# Epoch: 117 | Discriminator Loss: 0.351480 | Generator Loss: 1.598903
# 5/5 [==============================] - 3s 510ms/step
# Epoch: 118 | Discriminator Loss: 0.320054 | Generator Loss: 1.815355
# 5/5 [==============================] - 3s 511ms/step
# Epoch: 119 | Discriminator Loss: 0.302548 | Generator Loss: 1.815829
# 5/5 [==============================] - 3s 506ms/step
# Epoch: 120 | Discriminator Loss: 0.295384 | Generator Loss: 1.817100
# 5/5 [==============================] - 3s 501ms/step
# Epoch: 121 | Discriminator Loss: 0.286479 | Generator Loss: 2.068503
# 5/5 [==============================] - 3s 506ms/step
# Epoch: 122 | Discriminator Loss: 0.280431 | Generator Loss: 2.276217
# 5/5 [==============================] - 3s 504ms/step
# Epoch: 123 | Discriminator Loss: 0.278925 | Generator Loss: 2.325097
# 5/5 [==============================] - 3s 506ms/step
# Epoch: 124 | Discriminator Loss: 0.275812 | Generator Loss: 2.453530
# 5/5 [==============================] - 3s 504ms/step
# Epoch: 125 | Discriminator Loss: 0.272056 | Generator Loss: 2.589200
# 5/5 [==============================] - 2s 499ms/step
# Epoch: 126 | Discriminator Loss: 0.268317 | Generator Loss: 2.804880
# 5/5 [==============================] - 2s 500ms/step
# Epoch: 127 | Discriminator Loss: 0.264723 | Generator Loss: 2.933621
# 5/5 [==============================] - 3s 506ms/step
# Epoch: 128 | Discriminator Loss: 0.262650 | Generator Loss: 3.145387
# 5/5 [==============================] - 3s 506ms/step
# Epoch: 129 | Discriminator Loss: 0.261424 | Generator Loss: 3.316054
# 5/5 [==============================] - 3s 508ms/step
# Epoch: 130 | Discriminator Loss: 0.258486 | Generator Loss: 3.487103
# 5/5 [==============================] - 3s 507ms/step
# Epoch: 131 | Discriminator Loss: 0.257883 | Generator Loss: 3.550286
# 5/5 [==============================] - 3s 506ms/step
# Epoch: 132 | Discriminator Loss: 0.257452 | Generator Loss: 3.562781
# 5/5 [==============================] - 3s 508ms/step
# Epoch: 133 | Discriminator Loss: 0.257515 | Generator Loss: 3.619033
# 5/5 [==============================] - 3s 504ms/step
# Epoch: 134 | Discriminator Loss: 0.257400 | Generator Loss: 3.530166
# 5/5 [==============================] - 3s 506ms/step
# Epoch: 135 | Discriminator Loss: 0.259917 | Generator Loss: 3.480040
# 5/5 [==============================] - 3s 504ms/step
# Epoch: 136 | Discriminator Loss: 0.260482 | Generator Loss: 3.455483
# 5/5 [==============================] - 3s 502ms/step
# Epoch: 137 | Discriminator Loss: 0.261297 | Generator Loss: 3.485372
# 5/5 [==============================] - 2s 498ms/step
# Epoch: 138 | Discriminator Loss: 0.262320 | Generator Loss: 3.492870
# 5/5 [==============================] - 2s 498ms/step
# Epoch: 139 | Discriminator Loss: 0.262469 | Generator Loss: 3.218770
# 5/5 [==============================] - 3s 502ms/step
# Epoch: 140 | Discriminator Loss: 0.268169 | Generator Loss: 2.909413
# 5/5 [==============================] - 3s 507ms/step
# Epoch: 141 | Discriminator Loss: 0.270132 | Generator Loss: 2.455475
# 5/5 [==============================] - 3s 506ms/step
# Epoch: 142 | Discriminator Loss: 0.278853 | Generator Loss: 1.831968
# 5/5 [==============================] - 3s 506ms/step
# Epoch: 143 | Discriminator Loss: 0.294862 | Generator Loss: 1.206819
# 5/5 [==============================] - 3s 508ms/step
# Epoch: 144 | Discriminator Loss: 0.306331 | Generator Loss: 0.758508
# 5/5 [==============================] - 3s 506ms/step
# Epoch: 145 | Discriminator Loss: 0.312828 | Generator Loss: 1.260613
# 5/5 [==============================] - 3s 508ms/step
# Epoch: 146 | Discriminator Loss: 0.313505 | Generator Loss: 3.203139
# 5/5 [==============================] - 3s 508ms/step
# Epoch: 147 | Discriminator Loss: 0.292949 | Generator Loss: 4.033517
# 5/5 [==============================] - 3s 507ms/step
# Epoch: 148 | Discriminator Loss: 0.285476 | Generator Loss: 3.224397
# 5/5 [==============================] - 3s 509ms/step
# Epoch: 149 | Discriminator Loss: 0.285732 | Generator Loss: 2.837291
# 5/5 [==============================] - 3s 505ms/step
# Epoch: 150 | Discriminator Loss: 0.278734 | Generator Loss: 3.059157
# 5/5 [==============================] - 3s 503ms/step
# Epoch: 151 | Discriminator Loss: 0.280505 | Generator Loss: 2.549752
# 5/5 [==============================] - 3s 509ms/step
# Epoch: 152 | Discriminator Loss: 0.284235 | Generator Loss: 2.361906
# 5/5 [==============================] - 3s 504ms/step
# Epoch: 153 | Discriminator Loss: 0.278273 | Generator Loss: 2.431027
# 5/5 [==============================] - 3s 505ms/step
# Epoch: 154 | Discriminator Loss: 0.279041 | Generator Loss: 2.304166
# 5/5 [==============================] - 2s 496ms/step
# Epoch: 155 | Discriminator Loss: 0.278698 | Generator Loss: 2.122641
# 5/5 [==============================] - 2s 496ms/step
# Epoch: 156 | Discriminator Loss: 0.276544 | Generator Loss: 2.289187
# 5/5 [==============================] - 2s 498ms/step
# Epoch: 157 | Discriminator Loss: 0.281010 | Generator Loss: 1.932758
# 5/5 [==============================] - 3s 504ms/step
# Epoch: 158 | Discriminator Loss: 0.290040 | Generator Loss: 1.479593
# 5/5 [==============================] - 3s 507ms/step
# Epoch: 159 | Discriminator Loss: 0.289220 | Generator Loss: 1.117063
# 5/5 [==============================] - 3s 506ms/step
# Epoch: 160 | Discriminator Loss: 0.291965 | Generator Loss: 0.938018
# 5/5 [==============================] - 3s 507ms/step
# Epoch: 161 | Discriminator Loss: 0.283017 | Generator Loss: 1.208632
# 5/5 [==============================] - 3s 504ms/step
# Epoch: 162 | Discriminator Loss: 0.286500 | Generator Loss: 1.218744
# 5/5 [==============================] - 3s 508ms/step
# Epoch: 163 | Discriminator Loss: 0.285389 | Generator Loss: 1.273640
# 5/5 [==============================] - 3s 510ms/step
# Epoch: 164 | Discriminator Loss: 0.284527 | Generator Loss: 1.490261
# 5/5 [==============================] - 3s 508ms/step
# Epoch: 165 | Discriminator Loss: 0.279180 | Generator Loss: 1.731384
# 5/5 [==============================] - 3s 510ms/step
# Epoch: 166 | Discriminator Loss: 0.276686 | Generator Loss: 1.521832
# 5/5 [==============================] - 3s 508ms/step
# Epoch: 167 | Discriminator Loss: 0.269047 | Generator Loss: 1.470587
# 5/5 [==============================] - 3s 503ms/step
# Epoch: 168 | Discriminator Loss: 0.288319 | Generator Loss: 1.237879
# 5/5 [==============================] - 3s 504ms/step
# Epoch: 169 | Discriminator Loss: 0.283423 | Generator Loss: 1.280051
# 5/5 [==============================] - 3s 509ms/step
# Epoch: 170 | Discriminator Loss: 0.276276 | Generator Loss: 1.041191
# 5/5 [==============================] - 3s 507ms/step
# Epoch: 171 | Discriminator Loss: 0.280143 | Generator Loss: 0.660855
# 5/5 [==============================] - 3s 506ms/step
# Epoch: 172 | Discriminator Loss: 0.275702 | Generator Loss: 0.447308
# 5/5 [==============================] - 3s 506ms/step
# Epoch: 173 | Discriminator Loss: 0.261393 | Generator Loss: 0.399343
# 5/5 [==============================] - 3s 507ms/step
# Epoch: 174 | Discriminator Loss: 0.259741 | Generator Loss: 0.152300
# 5/5 [==============================] - 3s 506ms/step
# Epoch: 175 | Discriminator Loss: 0.255930 | Generator Loss: 0.192850
# 5/5 [==============================] - 3s 506ms/step
# Epoch: 176 | Discriminator Loss: 0.254975 | Generator Loss: 0.093317
# 5/5 [==============================] - 3s 503ms/step
# Epoch: 177 | Discriminator Loss: 0.253989 | Generator Loss: 0.099675
# 5/5 [==============================] - 2s 498ms/step
# Epoch: 178 | Discriminator Loss: 0.254649 | Generator Loss: 0.099171
# 5/5 [==============================] - 2s 500ms/step
# Epoch: 179 | Discriminator Loss: 0.253794 | Generator Loss: 0.144513
# 5/5 [==============================] - 3s 505ms/step
# Epoch: 180 | Discriminator Loss: 0.255324 | Generator Loss: 0.127307
# 5/5 [==============================] - 3s 503ms/step
# Epoch: 181 | Discriminator Loss: 0.255165 | Generator Loss: 0.110184
# 5/5 [==============================] - 3s 506ms/step
# Epoch: 182 | Discriminator Loss: 0.255225 | Generator Loss: 0.120130
# 5/5 [==============================] - 3s 508ms/step
# Epoch: 183 | Discriminator Loss: 0.256318 | Generator Loss: 0.111466
# 5/5 [==============================] - 3s 504ms/step
# Epoch: 184 | Discriminator Loss: 0.255820 | Generator Loss: 0.098343
# 5/5 [==============================] - 3s 503ms/step
# Epoch: 185 | Discriminator Loss: 0.255940 | Generator Loss: 0.072297
# 5/5 [==============================] - 3s 505ms/step
# Epoch: 186 | Discriminator Loss: 0.254795 | Generator Loss: 0.056555
# 5/5 [==============================] - 3s 507ms/step
# Epoch: 187 | Discriminator Loss: 0.255159 | Generator Loss: 0.066116
# 5/5 [==============================] - 3s 507ms/step
# Epoch: 188 | Discriminator Loss: 0.254107 | Generator Loss: 0.025792
# 5/5 [==============================] - 3s 503ms/step
# Epoch: 189 | Discriminator Loss: 0.253820 | Generator Loss: 0.035952
# 5/5 [==============================] - 3s 507ms/step
# Epoch: 190 | Discriminator Loss: 0.252751 | Generator Loss: 0.022802
# 5/5 [==============================] - 3s 505ms/step
# Epoch: 191 | Discriminator Loss: 0.253048 | Generator Loss: 0.017683
# 5/5 [==============================] - 3s 508ms/step
# Epoch: 192 | Discriminator Loss: 0.252231 | Generator Loss: 0.019249
# 5/5 [==============================] - 3s 507ms/step
# Epoch: 193 | Discriminator Loss: 0.252272 | Generator Loss: 0.017654
# 5/5 [==============================] - 3s 506ms/step
# Epoch: 194 | Discriminator Loss: 0.252290 | Generator Loss: 0.023825
# 5/5 [==============================] - 3s 507ms/step
# Epoch: 195 | Discriminator Loss: 0.252444 | Generator Loss: 0.015207
# 5/5 [==============================] - 3s 505ms/step
# Epoch: 196 | Discriminator Loss: 0.252405 | Generator Loss: 0.026934
# 5/5 [==============================] - 3s 507ms/step
# Epoch: 197 | Discriminator Loss: 0.252136 | Generator Loss: 0.017082
# 5/5 [==============================] - 3s 506ms/step
# Epoch: 198 | Discriminator Loss: 0.252380 | Generator Loss: 0.014714
# 5/5 [==============================] - 3s 504ms/step
# Epoch: 199 | Discriminator Loss: 0.252135 | Generator Loss: 0.020286
# 5/5 [==============================] - 2s 498ms/step
# Epoch: 200 | Discriminator Loss: 0.252200 | Generator Loss: 0.023161
# 5/5 [==============================] - 3s 610ms/step
# Epoch: 201 | Discriminator Loss: 0.252670 | Generator Loss: 0.020923
# 5/5 [==============================] - 2s 495ms/step
# Epoch: 202 | Discriminator Loss: 0.252251 | Generator Loss: 0.027233
# 5/5 [==============================] - 2s 499ms/step
# Epoch: 203 | Discriminator Loss: 0.252480 | Generator Loss: 0.025185
# 5/5 [==============================] - 3s 503ms/step
# Epoch: 204 | Discriminator Loss: 0.253063 | Generator Loss: 0.019848
# 5/5 [==============================] - 3s 502ms/step
# Epoch: 205 | Discriminator Loss: 0.252034 | Generator Loss: 0.031948
# 5/5 [==============================] - 3s 507ms/step
# Epoch: 206 | Discriminator Loss: 0.252584 | Generator Loss: 0.031773
# 5/5 [==============================] - 3s 507ms/step
# Epoch: 207 | Discriminator Loss: 0.253160 | Generator Loss: 0.039518
# 5/5 [==============================] - 3s 507ms/step
# Epoch: 208 | Discriminator Loss: 0.252594 | Generator Loss: 0.044947
# 5/5 [==============================] - 3s 509ms/step
# Epoch: 209 | Discriminator Loss: 0.253681 | Generator Loss: 0.041595
# 5/5 [==============================] - 3s 506ms/step
# Epoch: 210 | Discriminator Loss: 0.252544 | Generator Loss: 0.040600
# 5/5 [==============================] - 3s 509ms/step
# Epoch: 211 | Discriminator Loss: 0.253522 | Generator Loss: 0.026186
# 5/5 [==============================] - 3s 508ms/step
# Epoch: 212 | Discriminator Loss: 0.252705 | Generator Loss: 0.053220
# 5/5 [==============================] - 3s 506ms/step
# Epoch: 213 | Discriminator Loss: 0.254068 | Generator Loss: 0.046883
# 5/5 [==============================] - 3s 508ms/step
# Epoch: 214 | Discriminator Loss: 0.253392 | Generator Loss: 0.033374
# 5/5 [==============================] - 3s 505ms/step
# Epoch: 215 | Discriminator Loss: 0.253505 | Generator Loss: 0.034718
# 5/5 [==============================] - 3s 506ms/step
# Epoch: 216 | Discriminator Loss: 0.253479 | Generator Loss: 0.038049
# 5/5 [==============================] - 3s 508ms/step
# Epoch: 217 | Discriminator Loss: 0.254738 | Generator Loss: 0.032718
# 5/5 [==============================] - 3s 509ms/step
# Epoch: 218 | Discriminator Loss: 0.252902 | Generator Loss: 0.051527
# 5/5 [==============================] - 3s 507ms/step
# Epoch: 219 | Discriminator Loss: 0.255880 | Generator Loss: 0.023751
# 5/5 [==============================] - 3s 506ms/step
# Epoch: 220 | Discriminator Loss: 0.253703 | Generator Loss: 0.053951
# 5/5 [==============================] - 3s 507ms/step
# Epoch: 221 | Discriminator Loss: 0.255510 | Generator Loss: 0.026102
# 5/5 [==============================] - 3s 506ms/step
# Epoch: 222 | Discriminator Loss: 0.253948 | Generator Loss: 0.062289
# 5/5 [==============================] - 3s 507ms/step
# Epoch: 223 | Discriminator Loss: 0.257010 | Generator Loss: 0.026867
# 5/5 [==============================] - 3s 505ms/step
# Epoch: 224 | Discriminator Loss: 0.253656 | Generator Loss: 0.038860
# 5/5 [==============================] - 3s 506ms/step
# Epoch: 225 | Discriminator Loss: 0.254996 | Generator Loss: 0.033229
# 5/5 [==============================] - 3s 506ms/step
# Epoch: 226 | Discriminator Loss: 0.255103 | Generator Loss: 0.056250
# 5/5 [==============================] - 3s 508ms/step
# Epoch: 227 | Discriminator Loss: 0.256007 | Generator Loss: 0.054661
# 5/5 [==============================] - 3s 507ms/step
# Epoch: 228 | Discriminator Loss: 0.256501 | Generator Loss: 0.079755
# 5/5 [==============================] - 3s 509ms/step
# Epoch: 229 | Discriminator Loss: 0.259617 | Generator Loss: 0.207890
# 5/5 [==============================] - 3s 506ms/step
# Epoch: 230 | Discriminator Loss: 0.265767 | Generator Loss: 0.240479
# 5/5 [==============================] - 3s 506ms/step
# Epoch: 231 | Discriminator Loss: 0.268281 | Generator Loss: 0.202113
# 5/5 [==============================] - 3s 507ms/step
# Epoch: 232 | Discriminator Loss: 0.261693 | Generator Loss: 0.314703
# 5/5 [==============================] - 3s 505ms/step
# Epoch: 233 | Discriminator Loss: 0.272950 | Generator Loss: 1.184320
# 5/5 [==============================] - 3s 503ms/step
# Epoch: 234 | Discriminator Loss: 0.269275 | Generator Loss: 0.563534
# 5/5 [==============================] - 2s 497ms/step
# Epoch: 235 | Discriminator Loss: 0.264285 | Generator Loss: 0.349922
# 5/5 [==============================] - 3s 502ms/step
# Epoch: 236 | Discriminator Loss: 0.263653 | Generator Loss: 0.409886
# 5/5 [==============================] - 3s 503ms/step
# Epoch: 237 | Discriminator Loss: 0.262789 | Generator Loss: 0.176147
# 5/5 [==============================] - 3s 506ms/step
# Epoch: 238 | Discriminator Loss: 0.257087 | Generator Loss: 0.039624
# 5/5 [==============================] - 3s 507ms/step
# Epoch: 239 | Discriminator Loss: 0.252256 | Generator Loss: 0.029908
# 5/5 [==============================] - 3s 506ms/step
# Epoch: 240 | Discriminator Loss: 0.253183 | Generator Loss: 0.016898
# 5/5 [==============================] - 3s 506ms/step
# Epoch: 241 | Discriminator Loss: 0.251360 | Generator Loss: 0.041154
# 5/5 [==============================] - 3s 506ms/step
# Epoch: 242 | Discriminator Loss: 0.252578 | Generator Loss: 0.017182
# 5/5 [==============================] - 3s 510ms/step
# Epoch: 243 | Discriminator Loss: 0.251502 | Generator Loss: 0.035367
# 5/5 [==============================] - 3s 506ms/step
# Epoch: 244 | Discriminator Loss: 0.251559 | Generator Loss: 0.017535
# 5/5 [==============================] - 3s 511ms/step
# Epoch: 245 | Discriminator Loss: 0.251822 | Generator Loss: 0.011595
# 5/5 [==============================] - 3s 506ms/step
# Epoch: 246 | Discriminator Loss: 0.251406 | Generator Loss: 0.015090
# 5/5 [==============================] - 3s 507ms/step
# Epoch: 247 | Discriminator Loss: 0.251552 | Generator Loss: 0.029108
# 5/5 [==============================] - 3s 505ms/step
# Epoch: 248 | Discriminator Loss: 0.251547 | Generator Loss: 0.016468
# 5/5 [==============================] - 3s 507ms/step
# Epoch: 249 | Discriminator Loss: 0.251693 | Generator Loss: 0.018184
# 5/5 [==============================] - 3s 507ms/step
# Epoch: 250 | Discriminator Loss: 0.251699 | Generator Loss: 0.025781
# 5/5 [==============================] - 3s 504ms/step
# Epoch: 251 | Discriminator Loss: 0.251333 | Generator Loss: 0.015448
# 5/5 [==============================] - 3s 504ms/step
# Epoch: 252 | Discriminator Loss: 0.251712 | Generator Loss: 0.015897
# 5/5 [==============================] - 3s 501ms/step
# Epoch: 253 | Discriminator Loss: 0.251325 | Generator Loss: 0.016331
# 5/5 [==============================] - 3s 505ms/step
# Epoch: 254 | Discriminator Loss: 0.251168 | Generator Loss: 0.011846
# 5/5 [==============================] - 3s 506ms/step
# Epoch: 255 | Discriminator Loss: 0.251071 | Generator Loss: 0.011263
# 5/5 [==============================] - 3s 507ms/step
# Epoch: 256 | Discriminator Loss: 0.251336 | Generator Loss: 0.014347
# 5/5 [==============================] - 3s 502ms/step
# Epoch: 257 | Discriminator Loss: 0.251120 | Generator Loss: 0.012561
# 5/5 [==============================] - 3s 509ms/step
# Epoch: 258 | Discriminator Loss: 0.250864 | Generator Loss: 0.012856
# 5/5 [==============================] - 3s 505ms/step
# Epoch: 259 | Discriminator Loss: 0.251007 | Generator Loss: 0.008258
# 5/5 [==============================] - 3s 508ms/step
# Epoch: 260 | Discriminator Loss: 0.251130 | Generator Loss: 0.008508
# 5/5 [==============================] - 3s 506ms/step
# Epoch: 261 | Discriminator Loss: 0.250808 | Generator Loss: 0.012292
# 5/5 [==============================] - 3s 506ms/step
# Epoch: 262 | Discriminator Loss: 0.251079 | Generator Loss: 0.009476
# 5/5 [==============================] - 3s 509ms/step
# Epoch: 263 | Discriminator Loss: 0.250860 | Generator Loss: 0.012409
# 5/5 [==============================] - 3s 506ms/step
# Epoch: 264 | Discriminator Loss: 0.250899 | Generator Loss: 0.006961
# 5/5 [==============================] - 3s 507ms/step
# Epoch: 265 | Discriminator Loss: 0.251030 | Generator Loss: 0.008638
# 5/5 [==============================] - 3s 507ms/step
# Epoch: 266 | Discriminator Loss: 0.250824 | Generator Loss: 0.012070
# 5/5 [==============================] - 3s 501ms/step
# Epoch: 267 | Discriminator Loss: 0.250856 | Generator Loss: 0.011237
# 5/5 [==============================] - 2s 500ms/step
# Epoch: 268 | Discriminator Loss: 0.251054 | Generator Loss: 0.004433
# 5/5 [==============================] - 3s 503ms/step
# Epoch: 269 | Discriminator Loss: 0.250795 | Generator Loss: 0.007191
# 5/5 [==============================] - 3s 505ms/step
# Epoch: 270 | Discriminator Loss: 0.250668 | Generator Loss: 0.008734
# 5/5 [==============================] - 3s 503ms/step
# Epoch: 271 | Discriminator Loss: 0.250804 | Generator Loss: 0.016253
# 5/5 [==============================] - 3s 506ms/step
# Epoch: 272 | Discriminator Loss: 0.250921 | Generator Loss: 0.006012
# 5/5 [==============================] - 3s 507ms/step
# Epoch: 273 | Discriminator Loss: 0.250771 | Generator Loss: 0.011023
# 5/5 [==============================] - 3s 505ms/step
# Epoch: 274 | Discriminator Loss: 0.250843 | Generator Loss: 0.008377
# 5/5 [==============================] - 3s 507ms/step
# Epoch: 275 | Discriminator Loss: 0.250837 | Generator Loss: 0.011721
# 5/5 [==============================] - 3s 506ms/step
# Epoch: 276 | Discriminator Loss: 0.250979 | Generator Loss: 0.008894
# 5/5 [==============================] - 3s 507ms/step
# Epoch: 277 | Discriminator Loss: 0.250948 | Generator Loss: 0.015958
# 5/5 [==============================] - 3s 510ms/step
# Epoch: 278 | Discriminator Loss: 0.251003 | Generator Loss: 0.009255
# 5/5 [==============================] - 3s 511ms/step
# Epoch: 279 | Discriminator Loss: 0.251047 | Generator Loss: 0.012629
# 5/5 [==============================] - 3s 509ms/step
# Epoch: 280 | Discriminator Loss: 0.250723 | Generator Loss: 0.008915
# 5/5 [==============================] - 3s 509ms/step
# Epoch: 281 | Discriminator Loss: 0.250980 | Generator Loss: 0.010137
# 5/5 [==============================] - 3s 509ms/step
# Epoch: 282 | Discriminator Loss: 0.251052 | Generator Loss: 0.009808
# 5/5 [==============================] - 3s 508ms/step
# Epoch: 283 | Discriminator Loss: 0.250861 | Generator Loss: 0.015225
# 5/5 [==============================] - 3s 507ms/step
# Epoch: 284 | Discriminator Loss: 0.251040 | Generator Loss: 0.009436
# 5/5 [==============================] - 3s 506ms/step
# Epoch: 285 | Discriminator Loss: 0.250976 | Generator Loss: 0.010260
# 5/5 [==============================] - 3s 509ms/step
# Epoch: 286 | Discriminator Loss: 0.250773 | Generator Loss: 0.014181
# 5/5 [==============================] - 3s 508ms/step
# Epoch: 287 | Discriminator Loss: 0.251100 | Generator Loss: 0.009384
# 5/5 [==============================] - 3s 509ms/step
# Epoch: 288 | Discriminator Loss: 0.250739 | Generator Loss: 0.011489
# 5/5 [==============================] - 3s 510ms/step
# Epoch: 289 | Discriminator Loss: 0.250911 | Generator Loss: 0.009259
# 5/5 [==============================] - 3s 507ms/step
# Epoch: 290 | Discriminator Loss: 0.251458 | Generator Loss: 0.022325
# 5/5 [==============================] - 3s 505ms/step
# Epoch: 291 | Discriminator Loss: 0.250769 | Generator Loss: 0.021232
# 5/5 [==============================] - 3s 507ms/step
# Epoch: 292 | Discriminator Loss: 0.251202 | Generator Loss: 0.012325
# 5/5 [==============================] - 3s 507ms/step
# Epoch: 293 | Discriminator Loss: 0.251670 | Generator Loss: 0.040509
# 5/5 [==============================] - 3s 505ms/step
# Epoch: 294 | Discriminator Loss: 0.251902 | Generator Loss: 0.019718
# 5/5 [==============================] - 3s 507ms/step
# Epoch: 295 | Discriminator Loss: 0.251396 | Generator Loss: 0.037709
# 5/5 [==============================] - 3s 506ms/step
# Epoch: 296 | Discriminator Loss: 0.252256 | Generator Loss: 0.024268
# 5/5 [==============================] - 3s 507ms/step
# Epoch: 297 | Discriminator Loss: 0.251497 | Generator Loss: 0.054589
# 5/5 [==============================] - 3s 507ms/step
# Epoch: 298 | Discriminator Loss: 0.253384 | Generator Loss: 0.075170
# 5/5 [==============================] - 3s 506ms/step
# Epoch: 299 | Discriminator Loss: 0.253397 | Generator Loss: 0.066117
# 5/5 [==============================] - 3s 505ms/step
# Epoch: 300 | Discriminator Loss: 0.253747 | Generator Loss: 0.101467
# 5/5 [==============================] - 2s 499ms/step
# Epoch: 301 | Discriminator Loss: 0.256937 | Generator Loss: 0.115182
# 5/5 [==============================] - 3s 501ms/step
# Epoch: 302 | Discriminator Loss: 0.260408 | Generator Loss: 0.750577
# 5/5 [==============================] - 3s 503ms/step
# Epoch: 303 | Discriminator Loss: 0.266906 | Generator Loss: 0.778346
# 5/5 [==============================] - 3s 506ms/step
# Epoch: 304 | Discriminator Loss: 0.255991 | Generator Loss: 0.273709
# 5/5 [==============================] - 3s 508ms/step
# Epoch: 305 | Discriminator Loss: 0.256693 | Generator Loss: 0.114220
# 5/5 [==============================] - 3s 508ms/step
# Epoch: 306 | Discriminator Loss: 0.253563 | Generator Loss: 0.042997
# 5/5 [==============================] - 3s 506ms/step
# Epoch: 307 | Discriminator Loss: 0.252281 | Generator Loss: 0.050685
# 5/5 [==============================] - 3s 507ms/step
# Epoch: 308 | Discriminator Loss: 0.251361 | Generator Loss: 0.012281
# 5/5 [==============================] - 3s 508ms/step
# Epoch: 309 | Discriminator Loss: 0.250992 | Generator Loss: 0.012228
# 5/5 [==============================] - 3s 512ms/step
# Epoch: 310 | Discriminator Loss: 0.250925 | Generator Loss: 0.011398
# 5/5 [==============================] - 3s 507ms/step
# Epoch: 311 | Discriminator Loss: 0.250872 | Generator Loss: 0.010781
# 5/5 [==============================] - 3s 506ms/step
# Epoch: 312 | Discriminator Loss: 0.250667 | Generator Loss: 0.012024
# 5/5 [==============================] - 3s 506ms/step
# Epoch: 313 | Discriminator Loss: 0.250725 | Generator Loss: 0.012909
# 5/5 [==============================] - 3s 507ms/step
# Epoch: 314 | Discriminator Loss: 0.250604 | Generator Loss: 0.015237
# 5/5 [==============================] - 3s 507ms/step
# Epoch: 315 | Discriminator Loss: 0.250813 | Generator Loss: 0.010736
# 5/5 [==============================] - 3s 508ms/step
# Epoch: 316 | Discriminator Loss: 0.250588 | Generator Loss: 0.012164
# 5/5 [==============================] - 3s 507ms/step
# Epoch: 317 | Discriminator Loss: 0.250649 | Generator Loss: 0.015291
# 5/5 [==============================] - 3s 508ms/step
# Epoch: 318 | Discriminator Loss: 0.250685 | Generator Loss: 0.010196
# 5/5 [==============================] - 3s 504ms/step
# Epoch: 319 | Discriminator Loss: 0.250589 | Generator Loss: 0.010045
# 5/5 [==============================] - 3s 504ms/step
# Epoch: 320 | Discriminator Loss: 0.250632 | Generator Loss: 0.012089
# 5/5 [==============================] - 3s 500ms/step
# Epoch: 321 | Discriminator Loss: 0.250641 | Generator Loss: 0.009624
# 5/5 [==============================] - 2s 494ms/step
# Epoch: 322 | Discriminator Loss: 0.250510 | Generator Loss: 0.013578
# 5/5 [==============================] - 3s 506ms/step
# Epoch: 323 | Discriminator Loss: 0.250637 | Generator Loss: 0.009228
# 5/5 [==============================] - 3s 502ms/step
# Epoch: 324 | Discriminator Loss: 0.250538 | Generator Loss: 0.009291
# 5/5 [==============================] - 3s 502ms/step
# Epoch: 325 | Discriminator Loss: 0.250574 | Generator Loss: 0.008029
# 5/5 [==============================] - 3s 505ms/step
# Epoch: 326 | Discriminator Loss: 0.250510 | Generator Loss: 0.008215
# 5/5 [==============================] - 3s 507ms/step
# Epoch: 327 | Discriminator Loss: 0.250608 | Generator Loss: 0.012677
# 5/5 [==============================] - 3s 506ms/step
# Epoch: 328 | Discriminator Loss: 0.250444 | Generator Loss: 0.012367
# 5/5 [==============================] - 3s 503ms/step
# Epoch: 329 | Discriminator Loss: 0.250609 | Generator Loss: 0.009485
# 5/5 [==============================] - 3s 505ms/step
# Epoch: 330 | Discriminator Loss: 0.250470 | Generator Loss: 0.007802
# 5/5 [==============================] - 3s 505ms/step
# Epoch: 331 | Discriminator Loss: 0.250528 | Generator Loss: 0.007004
# 5/5 [==============================] - 3s 507ms/step
# Epoch: 332 | Discriminator Loss: 0.250601 | Generator Loss: 0.012280
# 5/5 [==============================] - 3s 505ms/step
# Epoch: 333 | Discriminator Loss: 0.250523 | Generator Loss: 0.014890
# 5/5 [==============================] - 3s 507ms/step
# Epoch: 334 | Discriminator Loss: 0.250661 | Generator Loss: 0.008515
# 5/5 [==============================] - 2s 500ms/step
# Epoch: 335 | Discriminator Loss: 0.250583 | Generator Loss: 0.011467
# 5/5 [==============================] - 2s 498ms/step
# Epoch: 336 | Discriminator Loss: 0.250428 | Generator Loss: 0.010414
# 5/5 [==============================] - 3s 500ms/step
# Epoch: 337 | Discriminator Loss: 0.250443 | Generator Loss: 0.005211
# 5/5 [==============================] - 3s 508ms/step
# Epoch: 338 | Discriminator Loss: 0.250532 | Generator Loss: 0.005805
# 5/5 [==============================] - 3s 504ms/step
# Epoch: 339 | Discriminator Loss: 0.250565 | Generator Loss: 0.008480
# 5/5 [==============================] - 3s 504ms/step
# Epoch: 340 | Discriminator Loss: 0.250353 | Generator Loss: 0.010518
# 5/5 [==============================] - 2s 497ms/step
# Epoch: 341 | Discriminator Loss: 0.250441 | Generator Loss: 0.006020
# 5/5 [==============================] - 2s 498ms/step
# Epoch: 342 | Discriminator Loss: 0.250579 | Generator Loss: 0.005101
# 5/5 [==============================] - 3s 504ms/step
# Epoch: 343 | Discriminator Loss: 0.250495 | Generator Loss: 0.013551
# 5/5 [==============================] - 3s 501ms/step
# Epoch: 344 | Discriminator Loss: 0.250473 | Generator Loss: 0.011386
# 5/5 [==============================] - 3s 507ms/step
# Epoch: 345 | Discriminator Loss: 0.250540 | Generator Loss: 0.007551
# 5/5 [==============================] - 3s 506ms/step
# Epoch: 346 | Discriminator Loss: 0.250628 | Generator Loss: 0.008291
# 5/5 [==============================] - 3s 506ms/step
# Epoch: 347 | Discriminator Loss: 0.250501 | Generator Loss: 0.009653
# 5/5 [==============================] - 3s 504ms/step
# Epoch: 348 | Discriminator Loss: 0.250627 | Generator Loss: 0.017259
# 5/5 [==============================] - 3s 502ms/step
# Epoch: 349 | Discriminator Loss: 0.250725 | Generator Loss: 0.007407
# 5/5 [==============================] - 3s 507ms/step
# Epoch: 350 | Discriminator Loss: 0.250690 | Generator Loss: 0.014439
# 5/5 [==============================] - 3s 507ms/step
# Epoch: 351 | Discriminator Loss: 0.250564 | Generator Loss: 0.014755
# 5/5 [==============================] - 3s 506ms/step
# Epoch: 352 | Discriminator Loss: 0.250903 | Generator Loss: 0.012538
# 5/5 [==============================] - 3s 506ms/step
# Epoch: 353 | Discriminator Loss: 0.250915 | Generator Loss: 0.023693
# 5/5 [==============================] - 2s 495ms/step
# Epoch: 354 | Discriminator Loss: 0.250942 | Generator Loss: 0.021179
# 5/5 [==============================] - 2s 498ms/step
# Epoch: 355 | Discriminator Loss: 0.251112 | Generator Loss: 0.034651
# 5/5 [==============================] - 3s 506ms/step
# Epoch: 356 | Discriminator Loss: 0.251688 | Generator Loss: 0.051898
# 5/5 [==============================] - 3s 506ms/step
# Epoch: 357 | Discriminator Loss: 0.251912 | Generator Loss: 0.033303
# 5/5 [==============================] - 3s 505ms/step
# Epoch: 358 | Discriminator Loss: 0.252034 | Generator Loss: 0.052282
# 5/5 [==============================] - 3s 504ms/step
# Epoch: 359 | Discriminator Loss: 0.251553 | Generator Loss: 0.069753
# 5/5 [==============================] - 3s 505ms/step
# Epoch: 360 | Discriminator Loss: 0.252182 | Generator Loss: 0.027264
# 5/5 [==============================] - 3s 505ms/step
# Epoch: 361 | Discriminator Loss: 0.251692 | Generator Loss: 0.049317
# 5/5 [==============================] - 3s 504ms/step
# Epoch: 362 | Discriminator Loss: 0.251263 | Generator Loss: 0.020446
# 5/5 [==============================] - 3s 508ms/step
# Epoch: 363 | Discriminator Loss: 0.251407 | Generator Loss: 0.022973
# 5/5 [==============================] - 3s 504ms/step
# Epoch: 364 | Discriminator Loss: 0.251294 | Generator Loss: 0.027662
# 5/5 [==============================] - 2s 500ms/step
# Epoch: 365 | Discriminator Loss: 0.251344 | Generator Loss: 0.031751
# 5/5 [==============================] - 2s 498ms/step
# Epoch: 366 | Discriminator Loss: 0.251299 | Generator Loss: 0.017235
# 5/5 [==============================] - 3s 504ms/step
# Epoch: 367 | Discriminator Loss: 0.251331 | Generator Loss: 0.029423
# 5/5 [==============================] - 3s 503ms/step
# Epoch: 368 | Discriminator Loss: 0.251505 | Generator Loss: 0.035363
# 5/5 [==============================] - 3s 505ms/step
# Epoch: 369 | Discriminator Loss: 0.251351 | Generator Loss: 0.020868
# 5/5 [==============================] - 3s 510ms/step
# Epoch: 370 | Discriminator Loss: 0.251386 | Generator Loss: 0.021138
# 5/5 [==============================] - 3s 509ms/step
# Epoch: 371 | Discriminator Loss: 0.251408 | Generator Loss: 0.032127
# 5/5 [==============================] - 3s 508ms/step
# Epoch: 372 | Discriminator Loss: 0.251711 | Generator Loss: 0.032763
# 5/5 [==============================] - 3s 505ms/step
# Epoch: 373 | Discriminator Loss: 0.252065 | Generator Loss: 0.043716
# 5/5 [==============================] - 3s 507ms/step
# Epoch: 374 | Discriminator Loss: 0.252220 | Generator Loss: 0.063251
# 5/5 [==============================] - 3s 507ms/step
# Epoch: 375 | Discriminator Loss: 0.253223 | Generator Loss: 0.106224
# 5/5 [==============================] - 3s 509ms/step
# Epoch: 376 | Discriminator Loss: 0.253323 | Generator Loss: 0.098532
# 5/5 [==============================] - 3s 508ms/step
# Epoch: 377 | Discriminator Loss: 0.252482 | Generator Loss: 0.044223
# 5/5 [==============================] - 3s 505ms/step
# Epoch: 378 | Discriminator Loss: 0.251279 | Generator Loss: 0.011872
# 5/5 [==============================] - 3s 507ms/step
# Epoch: 379 | Discriminator Loss: 0.250898 | Generator Loss: 0.009218
# 5/5 [==============================] - 3s 504ms/step
# Epoch: 380 | Discriminator Loss: 0.250717 | Generator Loss: 0.009405
# 5/5 [==============================] - 3s 505ms/step
# Epoch: 381 | Discriminator Loss: 0.250702 | Generator Loss: 0.008884
# 5/5 [==============================] - 2s 500ms/step
# Epoch: 382 | Discriminator Loss: 0.250668 | Generator Loss: 0.008504
# 5/5 [==============================] - 2s 495ms/step
# Epoch: 383 | Discriminator Loss: 0.250642 | Generator Loss: 0.013915
# 5/5 [==============================] - 3s 506ms/step
# Epoch: 384 | Discriminator Loss: 0.250763 | Generator Loss: 0.012893
# 5/5 [==============================] - 3s 506ms/step
# Epoch: 385 | Discriminator Loss: 0.250822 | Generator Loss: 0.017634
# 5/5 [==============================] - 3s 506ms/step
# Epoch: 386 | Discriminator Loss: 0.250921 | Generator Loss: 0.017619
# 5/5 [==============================] - 3s 504ms/step
# Epoch: 387 | Discriminator Loss: 0.250921 | Generator Loss: 0.022147
# 5/5 [==============================] - 3s 505ms/step
# ...
# 5/5 [==============================] - 3s 508ms/step
# Epoch: 2072 | Discriminator Loss: 0.250000 | Generator Loss: 15.519262
# 5/5 [==============================] - 3s 506ms/step
# Epoch: 2073 | Discriminator Loss: 0.250000 | Generator Loss: 15.488287
# 5/5 [==============================] - 3s 505ms/step
# Epoch: 2074 | Discriminator Loss: 0.250000 | Generator Loss: 15.496880
# 5/5 [==============================] - 3s 504ms/step
# Epoch: 2075 | Discriminator Loss: 0.250000 | Generator Loss: 15.508840
# 5/5 [==============================] - 3s 500ms/step
# Epoch: 2076 | Discriminator Loss: 0.250000 | Generator Loss: 15.494928
# 5/5 [==============================] - 2s 496ms/step
# Epoch: 2077 | Discriminator Loss: 0.250000 | Generator Loss: 15.532850
# 5/5 [==============================] - 3s 503ms/step
# Epoch: 2078 | Discriminator Loss: 0.250000 | Generator Loss: 15.524341
# 5/5 [==============================] - 3s 501ms/step
# Epoch: 2079 | Discriminator Loss: 0.250000 | Generator Loss: 15.546385
# 5/5 [==============================] - 3s 507ms/step
# Epoch: 2080 | Discriminator Loss: 0.250000 | Generator Loss: 15.552028
# 5/5 [==============================] - 3s 513ms/step
# Epoch: 2081 | Discriminator Loss: 0.250000 | Generator Loss: 15.541464
# 5/5 [==============================] - 3s 510ms/step
# Epoch: 2082 | Discriminator Loss: 0.250000 | Generator Loss: 15.532309
# 5/5 [==============================] - 3s 504ms/step
# Epoch: 2083 | Discriminator Loss: 0.250000 | Generator Loss: 15.521851
# 5/5 [==============================] - 3s 507ms/step
# Epoch: 2084 | Discriminator Loss: 0.250000 | Generator Loss: 15.533368
# 5/5 [==============================] - 3s 505ms/step
# Epoch: 2085 | Discriminator Loss: 0.250000 | Generator Loss: 15.527756
# 5/5 [==============================] - 3s 508ms/step
# Epoch: 2086 | Discriminator Loss: 0.250000 | Generator Loss: 15.553042
# 5/5 [==============================] - 3s 507ms/step
# Epoch: 2087 | Discriminator Loss: 0.250000 | Generator Loss: 15.534696
# 5/5 [==============================] - 3s 505ms/step
# Epoch: 2088 | Discriminator Loss: 0.250000 | Generator Loss: 15.547175
# 5/5 [==============================] - 3s 506ms/step
# Epoch: 2089 | Discriminator Loss: 0.250000 | Generator Loss: 15.565907
# 5/5 [==============================] - 3s 507ms/step
# Epoch: 2090 | Discriminator Loss: 0.250000 | Generator Loss: 15.561823
# 5/5 [==============================] - 3s 507ms/step
# Epoch: 2091 | Discriminator Loss: 0.250000 | Generator Loss: 15.543207
# 5/5 [==============================] - 3s 507ms/step
# Epoch: 2092 | Discriminator Loss: 0.250000 | Generator Loss: 15.548340
# 5/5 [==============================] - 3s 502ms/step
# Epoch: 2093 | Discriminator Loss: 0.250000 | Generator Loss: 15.543544
# 5/5 [==============================] - 2s 498ms/step
# Epoch: 2094 | Discriminator Loss: 0.250000 | Generator Loss: 15.529811
# 5/5 [==============================] - 3s 506ms/step
# Epoch: 2095 | Discriminator Loss: 0.250000 | Generator Loss: 15.556813
# 5/5 [==============================] - 3s 504ms/step
# Epoch: 2096 | Discriminator Loss: 0.250000 | Generator Loss: 15.579405
# 5/5 [==============================] - 3s 503ms/step
# Epoch: 2097 | Discriminator Loss: 0.250000 | Generator Loss: 15.567302
# 5/5 [==============================] - 3s 505ms/step
# Epoch: 2098 | Discriminator Loss: 0.250000 | Generator Loss: 15.600761
# 5/5 [==============================] - 3s 504ms/step
# Epoch: 2099 | Discriminator Loss: 0.250000 | Generator Loss: 15.599989
# 5/5 [==============================] - 3s 502ms/step
# Epoch: 2100 | Discriminator Loss: 0.250000 | Generator Loss: 15.582942
# 5/5 [==============================] - 3s 503ms/step
# Epoch: 2101 | Discriminator Loss: 0.250000 | Generator Loss: 15.569464
# 5/5 [==============================] - 3s 507ms/step
# Epoch: 2102 | Discriminator Loss: 0.250000 | Generator Loss: 15.572660
# 5/5 [==============================] - 3s 507ms/step
# Epoch: 2103 | Discriminator Loss: 0.250000 | Generator Loss: 15.556570
# 5/5 [==============================] - 3s 507ms/step
# Epoch: 2104 | Discriminator Loss: 0.250000 | Generator Loss: 15.569366
# 5/5 [==============================] - 2s 494ms/step
# Epoch: 2105 | Discriminator Loss: 0.250000 | Generator Loss: 15.586308
# 5/5 [==============================] - 3s 501ms/step
# Epoch: 2106 | Discriminator Loss: 0.250000 | Generator Loss: 15.557299
# 5/5 [==============================] - 3s 502ms/step
# Epoch: 2107 | Discriminator Loss: 0.250000 | Generator Loss: 15.575430
# 5/5 [==============================] - 3s 503ms/step
# Epoch: 2108 | Discriminator Loss: 0.250000 | Generator Loss: 15.581505
# 5/5 [==============================] - 3s 504ms/step
# Epoch: 2109 | Discriminator Loss: 0.250000 | Generator Loss: 15.580495
# 5/5 [==============================] - 3s 507ms/step
# Epoch: 2110 | Discriminator Loss: 0.250000 | Generator Loss: 15.572989
# 5/5 [==============================] - 3s 505ms/step
# Epoch: 2111 | Discriminator Loss: 0.250000 | Generator Loss: 15.564038
# 5/5 [==============================] - 2s 499ms/step
# Epoch: 2112 | Discriminator Loss: 0.250000 | Generator Loss: 15.549887
# 5/5 [==============================] - 2s 499ms/step
# Epoch: 2113 | Discriminator Loss: 0.250000 | Generator Loss: 15.561621
# 5/5 [==============================] - 3s 506ms/step
# Epoch: 2114 | Discriminator Loss: 0.250000 | Generator Loss: 15.558212
# 5/5 [==============================] - 3s 504ms/step
# Epoch: 2115 | Discriminator Loss: 0.250000 | Generator Loss: 15.565582
# 5/5 [==============================] - 3s 502ms/step
# Epoch: 2116 | Discriminator Loss: 0.250000 | Generator Loss: 15.565557
# 5/5 [==============================] - 3s 507ms/step
# Epoch: 2117 | Discriminator Loss: 0.250000 | Generator Loss: 15.564188
# 5/5 [==============================] - 3s 508ms/step
# Epoch: 2118 | Discriminator Loss: 0.250000 | Generator Loss: 15.553419
# 5/5 [==============================] - 3s 506ms/step
# Epoch: 2119 | Discriminator Loss: 0.250000 | Generator Loss: 15.557019
# 5/5 [==============================] - 3s 505ms/step
# Epoch: 2120 | Discriminator Loss: 0.250000 | Generator Loss: 15.557158
# 5/5 [==============================] - 3s 507ms/step
# Epoch: 2121 | Discriminator Loss: 0.250000 | Generator Loss: 15.583827
# 5/5 [==============================] - 3s 506ms/step
# Epoch: 2122 | Discriminator Loss: 0.250000 | Generator Loss: 15.584528
# 5/5 [==============================] - 3s 508ms/step
# Epoch: 2123 | Discriminator Loss: 0.250000 | Generator Loss: 15.583750
# 5/5 [==============================] - 3s 506ms/step
# Epoch: 2124 | Discriminator Loss: 0.250000 | Generator Loss: 15.591960
# 5/5 [==============================] - 2s 497ms/step
# Epoch: 2125 | Discriminator Loss: 0.250000 | Generator Loss: 15.600893
# 5/5 [==============================] - 2s 497ms/step
# Epoch: 2126 | Discriminator Loss: 0.250000 | Generator Loss: 15.604647
# 5/5 [==============================] - 3s 504ms/step
# Epoch: 2127 | Discriminator Loss: 0.250000 | Generator Loss: 15.572968
# 5/5 [==============================] - 3s 507ms/step
# Epoch: 2128 | Discriminator Loss: 0.250000 | Generator Loss: 15.596339
# 5/5 [==============================] - 3s 508ms/step
# Epoch: 2129 | Discriminator Loss: 0.250000 | Generator Loss: 15.583166
# 5/5 [==============================] - 3s 508ms/step
# Epoch: 2130 | Discriminator Loss: 0.250000 | Generator Loss: 15.592558
# 5/5 [==============================] - 3s 507ms/step
# Epoch: 2131 | Discriminator Loss: 0.250000 | Generator Loss: 15.607190
# 5/5 [==============================] - 3s 506ms/step
# Epoch: 2132 | Discriminator Loss: 0.250000 | Generator Loss: 15.601938
# 5/5 [==============================] - 3s 504ms/step
# Epoch: 2133 | Discriminator Loss: 0.250000 | Generator Loss: 15.608438
# 5/5 [==============================] - 3s 504ms/step
# Epoch: 2134 | Discriminator Loss: 0.250000 | Generator Loss: 15.604871
# 5/5 [==============================] - 2s 496ms/step
# Epoch: 2135 | Discriminator Loss: 0.250000 | Generator Loss: 15.596219
# 5/5 [==============================] - 2s 499ms/step
# Epoch: 2136 | Discriminator Loss: 0.250000 | Generator Loss: 15.600992
# 5/5 [==============================] - 3s 504ms/step
# Epoch: 2137 | Discriminator Loss: 0.250000 | Generator Loss: 15.622843
# 5/5 [==============================] - 3s 503ms/step
# Epoch: 2138 | Discriminator Loss: 0.250000 | Generator Loss: 15.610884
# 5/5 [==============================] - 3s 503ms/step
# Epoch: 2139 | Discriminator Loss: 0.250000 | Generator Loss: 15.618906
# 5/5 [==============================] - 3s 504ms/step
# Epoch: 2140 | Discriminator Loss: 0.250000 | Generator Loss: 15.614388
# 5/5 [==============================] - 3s 509ms/step
# Epoch: 2141 | Discriminator Loss: 0.250000 | Generator Loss: 15.669362
# 5/5 [==============================] - 3s 502ms/step
# Epoch: 2142 | Discriminator Loss: 0.250000 | Generator Loss: 15.642929
# 5/5 [==============================] - 2s 496ms/step
# Epoch: 2143 | Discriminator Loss: 0.250000 | Generator Loss: 15.651949
# 5/5 [==============================] - 2s 499ms/step
# Epoch: 2144 | Discriminator Loss: 0.250000 | Generator Loss: 15.631058
# 5/5 [==============================] - 2s 499ms/step
# Epoch: 2145 | Discriminator Loss: 0.250000 | Generator Loss: 15.659854
# 5/5 [==============================] - 3s 506ms/step
# Epoch: 2146 | Discriminator Loss: 0.250000 | Generator Loss: 15.632303
# 5/5 [==============================] - 3s 505ms/step
# Epoch: 2147 | Discriminator Loss: 0.250000 | Generator Loss: 15.652034
# 5/5 [==============================] - 3s 507ms/step
# Epoch: 2148 | Discriminator Loss: 0.250000 | Generator Loss: 15.640681
# 5/5 [==============================] - 3s 500ms/step
# Epoch: 2149 | Discriminator Loss: 0.250000 | Generator Loss: 15.640738
# 5/5 [==============================] - 2s 494ms/step
# Epoch: 2150 | Discriminator Loss: 0.250000 | Generator Loss: 15.642939
# 5/5 [==============================] - 3s 506ms/step
# Epoch: 2151 | Discriminator Loss: 0.250000 | Generator Loss: 15.647232
# 5/5 [==============================] - 3s 506ms/step
# Epoch: 2152 | Discriminator Loss: 0.250000 | Generator Loss: 15.674100
# 5/5 [==============================] - 3s 503ms/step
# Epoch: 2153 | Discriminator Loss: 0.250000 | Generator Loss: 15.685532
# 5/5 [==============================] - 3s 502ms/step
# Epoch: 2154 | Discriminator Loss: 0.250000 | Generator Loss: 15.674629
# 5/5 [==============================] - 3s 510ms/step
# Epoch: 2155 | Discriminator Loss: 0.250000 | Generator Loss: 15.677332
# 5/5 [==============================] - 3s 510ms/step
# Epoch: 2156 | Discriminator Loss: 0.250000 | Generator Loss: 15.675448
# 5/5 [==============================] - 3s 509ms/step
# Epoch: 2157 | Discriminator Loss: 0.250000 | Generator Loss: 15.684875
# 5/5 [==============================] - 3s 505ms/step
# Epoch: 2158 | Discriminator Loss: 0.250000 | Generator Loss: 15.673605
# 5/5 [==============================] - 3s 507ms/step
# Epoch: 2159 | Discriminator Loss: 0.250000 | Generator Loss: 15.668146
# 5/5 [==============================] - 3s 505ms/step
# Epoch: 2160 | Discriminator Loss: 0.250000 | Generator Loss: 15.677066
# 5/5 [==============================] - 2s 499ms/step
# Epoch: 2161 | Discriminator Loss: 0.250000 | Generator Loss: 15.712817
# 5/5 [==============================] - 2s 498ms/step
# Epoch: 2162 | Discriminator Loss: 0.250000 | Generator Loss: 15.709719
# 5/5 [==============================] - 3s 505ms/step
# Epoch: 2163 | Discriminator Loss: 0.250000 | Generator Loss: 15.703436
# 5/5 [==============================] - 3s 503ms/step
# Epoch: 2164 | Discriminator Loss: 0.250000 | Generator Loss: 15.695374
# 5/5 [==============================] - 3s 502ms/step
# Epoch: 2165 | Discriminator Loss: 0.250000 | Generator Loss: 15.707232
# 5/5 [==============================] - 3s 506ms/step
# Epoch: 2166 | Discriminator Loss: 0.250000 | Generator Loss: 15.690806
# 5/5 [==============================] - 3s 505ms/step
# Epoch: 2167 | Discriminator Loss: 0.250000 | Generator Loss: 15.694994
# 5/5 [==============================] - 3s 507ms/step
# Epoch: 2168 | Discriminator Loss: 0.250000 | Generator Loss: 15.711606
# 5/5 [==============================] - 3s 500ms/step
# Epoch: 2169 | Discriminator Loss: 0.250000 | Generator Loss: 15.709646
# 5/5 [==============================] - 2s 497ms/step
# Epoch: 2170 | Discriminator Loss: 0.250000 | Generator Loss: 15.709521
# 5/5 [==============================] - 3s 504ms/step
# Epoch: 2171 | Discriminator Loss: 0.250000 | Generator Loss: 15.732776
# 5/5 [==============================] - 3s 506ms/step
# Epoch: 2172 | Discriminator Loss: 0.250000 | Generator Loss: 15.756613
# 5/5 [==============================] - 3s 504ms/step
# Epoch: 2173 | Discriminator Loss: 0.250000 | Generator Loss: 15.746814
# 5/5 [==============================] - 3s 506ms/step
# Epoch: 2174 | Discriminator Loss: 0.250000 | Generator Loss: 15.722432
# 5/5 [==============================] - 3s 509ms/step
# Epoch: 2175 | Discriminator Loss: 0.250000 | Generator Loss: 15.699031
# 5/5 [==============================] - 3s 504ms/step
# Epoch: 2176 | Discriminator Loss: 0.250000 | Generator Loss: 15.701231
# 5/5 [==============================] - 3s 505ms/step
# Epoch: 2177 | Discriminator Loss: 0.250000 | Generator Loss: 15.730021
# 5/5 [==============================] - 3s 507ms/step
# Epoch: 2178 | Discriminator Loss: 0.250000 | Generator Loss: 15.729639
# 5/5 [==============================] - 3s 506ms/step
# Epoch: 2179 | Discriminator Loss: 0.250000 | Generator Loss: 15.706022
# 5/5 [==============================] - 3s 504ms/step
# Epoch: 2180 | Discriminator Loss: 0.250000 | Generator Loss: 15.742914
# 5/5 [==============================] - 2s 494ms/step
# Epoch: 2181 | Discriminator Loss: 0.250000 | Generator Loss: 15.726318
# 5/5 [==============================] - 2s 499ms/step
# Epoch: 2182 | Discriminator Loss: 0.250000 | Generator Loss: 15.749255
# 5/5 [==============================] - 3s 500ms/step
# Epoch: 2183 | Discriminator Loss: 0.250000 | Generator Loss: 15.739092
# 5/5 [==============================] - 3s 510ms/step
# Epoch: 2184 | Discriminator Loss: 0.250000 | Generator Loss: 15.760638
# 5/5 [==============================] - 3s 508ms/step
# Epoch: 2185 | Discriminator Loss: 0.250000 | Generator Loss: 15.752995
# 5/5 [==============================] - 3s 510ms/step
# Epoch: 2186 | Discriminator Loss: 0.250000 | Generator Loss: 15.749292
# 5/5 [==============================] - 3s 507ms/step
# Epoch: 2187 | Discriminator Loss: 0.250000 | Generator Loss: 15.773170
# 5/5 [==============================] - 3s 505ms/step
# Epoch: 2188 | Discriminator Loss: 0.250000 | Generator Loss: 15.747015
# 5/5 [==============================] - 3s 509ms/step
# Epoch: 2189 | Discriminator Loss: 0.250000 | Generator Loss: 15.770825
# 5/5 [==============================] - 3s 505ms/step
# Epoch: 2190 | Discriminator Loss: 0.250000 | Generator Loss: 15.767941
# 5/5 [==============================] - 3s 508ms/step
# Epoch: 2191 | Discriminator Loss: 0.250000 | Generator Loss: 15.771698
# 5/5 [==============================] - 3s 508ms/step
# Epoch: 2192 | Discriminator Loss: 0.250000 | Generator Loss: 15.793411
# 5/5 [==============================] - 3s 505ms/step
# Epoch: 2193 | Discriminator Loss: 0.250000 | Generator Loss: 15.797304
# 5/5 [==============================] - 3s 504ms/step
# Epoch: 2194 | Discriminator Loss: 0.250000 | Generator Loss: 15.804720
# 5/5 [==============================] - 3s 505ms/step
# Epoch: 2195 | Discriminator Loss: 0.250000 | Generator Loss: 15.822153
# 5/5 [==============================] - 3s 507ms/step
# Epoch: 2196 | Discriminator Loss: 0.250000 | Generator Loss: 15.810039
# 5/5 [==============================] - 3s 503ms/step
# Epoch: 2197 | Discriminator Loss: 0.250000 | Generator Loss: 15.832685
# 5/5 [==============================] - 2s 498ms/step
# Epoch: 2198 | Discriminator Loss: 0.250000 | Generator Loss: 15.822263
# 5/5 [==============================] - 3s 501ms/step
# Epoch: 2199 | Discriminator Loss: 0.250000 | Generator Loss: 15.849550
# 5/5 [==============================] - 3s 507ms/step
# Epoch: 2200 | Discriminator Loss: 0.250000 | Generator Loss: 15.838175

# %% [markdown]
# ### Generating Samples and Analysis
#
# - Plot your discriminator and generator losses and explain how it represents the MiniMax game in play, and comment on the trends you observe.
# - Generate random 5 noise samples and their corresponding fake images.
# - Mention if you observe any failure modes
# - **BONUS (5%):** Try generating some good samples, and try interpolating the input noise samples (Vector Arithmetic) to see if the results are as expected.

# %%
def plot_loss(gen_loss,disc_loss):
    plt.plot(gen_loss)
    plt.plot(disc_loss)
    plt.title('GAN Loss')
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend(['Generator', 'Discriminator'], loc='upper left')
    plt.show()

# %%
plot_loss(all_gen_loss,all_disc_loss)

# %% [markdown]
# #####Loss plot Analysis
#
# *  The GAN loss is very high and the losses dont converge, indicating convergence failure. The generator and discriminator are unable to reach a balance. Here, the performance of the generator is poor and it is unable to fool the discriminator.
# *   The generator is very unstable as the loss keeps decreasing and increasing sharply over epochs.
# <li> At each step, the generator wants to maximize its output but the discriminator wants to minimize its loss. They compete against one another, but need to find a balance where the generator is able to fool the discriminator into beleiving that the fake generated images are real. In the loss plot, the loss variation shows that its able to fool the discriminator for a while but then the discriminator learns and is again able to correctly classify fake images, increasing the generator's loss.

# %%
generator = build_generator()
generator.load_weights('/content/drive/My Drive/DLAS5/generator_uns')

# %%
for i in range(0,5):
  noise = sample_noise()
  grid = generator.predict(noise)
  save_samples(grid,i,save_at='final_part1')

# %% [markdown]
# #### Failure Modes observed in generated samples
# Mode Collapse: The images generated are near duplicates. All the samples generated from the trained model are identical, which means the generator fails to learn new features.<br>
# Convergence failure: The generator loss increases and the discriminator overpowers the generator. The generator is unable to learn well, as shown by the samples generated. Hardly any emoji is distinguishable.

# %%
# %pwd
# Out:
# '/content'

# %% [markdown]
# ## PART 2: Stablizing GANs
#
# In the first part, we trained our GAN using the standard methods proposed initially. In this part we will tweak our models and our training loop based on suggestions that deep learning researchers have come up with through their experiences. We will see if we encountered into typical problems faced while training GANs and see if these proposed methods improve our GANs and resolve issuse previously faced.

# %% [markdown]
# We have already implemented a GAN based on the recommendations made by Alec Radford, et al. in the 2015 paper titled [“Unsupervised Representation Learning with Deep Convolutional Generative Adversarial Networks.”](https://arxiv.org/abs/1511.06434)
#
#
#
# We have:
# 1. Downsampled using strided convolutions
# 2. Upsampled using strided convolutions
# 3. Used LeakyReLu in our discriminator, and ReLu in the generator and Tanh for the output of the generator.
# 4. Used BatchNormalization in both the discriminator and generator.

# %% [markdown]
# In addition to these, we will also make use of some more tips from the aforementioned paper, as well as tips from Soumith Chintala, who is one of the co-authors of the DCGAN paper in his [NIPS presentation](https://www.youtube.com/watch?v=X1mUN6dD8uE)

# %% [markdown]
# ### Modifications in the Models
#
# Here are some suggested modifications in the generator and discriminator models:
#
# - Use LeakyReLu in BOTH the generator and discriminator
# - Use Gaussian Weight initialization with mean=0 and std = 0.02. (Use the imported RandomNormal function to get weights and pass it in as the kernel_initializer argument in a convolutional layer)
# - Use Adam optimizer
#
# Make these modifications in your generator and discriminator models.

# %%
def build_discriminator_mod():
    weight_init = RandomNormal(mean=0, stddev=0.02)

    input1 = Input(shape = (64,64,3))
    conv31 = Conv2D(64,(4,4),padding='same',strides=(2,2),use_bias=False,
                    kernel_initializer=weight_init)(input1)
    leaky1 = LeakyReLU(alpha = 0.3)(conv31)
    conv32 = Conv2D(128,(4,4),padding='same',strides=(2,2),use_bias=False,
                    kernel_initializer=weight_init)(leaky1)
    batch1 = BatchNormalization()(conv32)
    leaky2 = LeakyReLU(alpha = 0.3)(batch1)
    conv33 = Conv2D(256,(4,4),padding='same',strides=(2,2),use_bias=False,
                    kernel_initializer=weight_init)(leaky2)
    batch2 = BatchNormalization()(conv33)
    leaky3 = LeakyReLU(alpha = 0.3)(batch2)
    conv34 = Conv2D(512,(4,4),padding='same',strides=(2,2),use_bias=False,
                    kernel_initializer=weight_init)(leaky3)
    batch3 = BatchNormalization()(conv34)
    leaky4 = LeakyReLU(alpha = 0.3)(batch3)
    conv35 = Conv2D(1,(2,2),padding='same',use_bias=False,
                    kernel_initializer=weight_init)(leaky3)
    flat1 = Flatten()(conv35)
    output = Dense(1,activation = 'sigmoid')(flat1)
    model_disc = Model(inputs=input1,outputs=output)

    adam = Adam(lr=0.0001)
    model_disc.compile(loss= 'binary_crossentropy',optimizer=adam, metrics=['accuracy'])

    return model_disc

# %%
def build_generator_mod():
  weight_init = RandomNormal(mean=0, stddev=0.02)

  input1 = Input(shape=(NOISE_DIM,))
  dense1 = Dense(4*4*1024)(input1)
  reshape = Reshape((4,4,1024))(dense1)

  tconv1 = Conv2DTranspose(512,(5,5),use_bias=False,padding='same',strides=(2,2),
                           kernel_initializer=weight_init)(reshape)
  batch1 = BatchNormalization()(tconv1)
  leaky1 = LeakyReLU(alpha = 0.3)(batch1)

  tconv2 = Conv2DTranspose(256,(5,5),use_bias=False,padding='same',strides=(2,2),
                           kernel_initializer=weight_init)(leaky1)
  batch2 = BatchNormalization()(tconv2)
  leaky2 = LeakyReLU(alpha = 0.3)(batch2)

  tconv3 = Conv2DTranspose(128,(5,5),use_bias=False,padding='same',strides=(2,2),
                           kernel_initializer=weight_init)(leaky2)
  batch3 = BatchNormalization()(tconv3)
  leaky3 = LeakyReLU(alpha = 0.3)(batch3)

  tconv4 = Conv2DTranspose(3,(5,5),use_bias=False,padding='same',strides=(2,2),activation='tanh',
                           kernel_initializer=weight_init)(leaky3)
  
  model_gen = Model(inputs=input1,outputs=tconv4)
  adam = Adam(lr=0.001)
  model_gen.compile(loss='categorical_crossentropy',optimizer=adam, metrics=['accuracy'])

  return model_gen

# %% [markdown]
# ### Scale Images to the Range [-1,1]
# We already know that normalizing images improves training for any model. We will scale our images in the range [-1,1] since we are using a tanh activation in our generator. This will make the fake generated images and real images in the same range and will enable our discriminator to learn better.
# Implement the following function to normalize a numpy array containing images. **Note:** The images will be in the range [0,255]

# %%
def normalize(images):
  norm_images = (images - 127.5) / 127.5
  return norm_images

# %% [markdown]
# ### Use Gaussian Latent Space
# Previously we have been using a uniform distribution to sample a latent space as recommended in the DCGAN paper, but more recently researchers suggest to use a Standard Gaussian distribution to sample the latent space. Modify the <code>sample_noise</code> function to sample fomr a Gaussian distribution.

# %%
def sample_noise_mod():
    return np.reshape(np.random.normal(0,1,(NOISE_DIM*BATCH_SIZE)),(BATCH_SIZE,NOISE_DIM))

# %% [markdown]
# ### Use Label Smoothing
# Normally, we use hard labels 1s and 0s to train our GANs. Researchers have suggested to smooth labels and use "soft" labels . This is said to have a "regularizing" effect on the training.

# %% [markdown]
# #### Real Label Smoothing
# For Real labels, i.e. 1s, we will smooth the labels uniformly between [0.7,1.2]. Use np.random.random for this.

# %%
def smooth_real_labels(y):
  shape = y.shape
  return y - 0.3 + (np.random.random(y.shape) * 0.5)

# %% [markdown]
# #### Fake Label Smoothing

# %%
def smooth_fake_labels(y):
  return y + np.random.random(y.shape) * 0.3

# %% [markdown]
# We will make use of these functions later in our training loop.

# %% [markdown]
# ### Train Discriminator with Real and Fake Images separately
# Previously we were combining our fake and real images batches and doing one update to our discriminator. Researchers suggest that the best practice is to train our discriminator in two updates, one for the real images and one for the fake images.

# %% [markdown]
# ### Flip some labels randomly while training the Generator
# Soumith Chintala also suggests that in practice, ocassionally flipping the labels of the generator may help (Swapping Real and Fake)

# %%
def flip_labels(y, prob=0.05):
  n_choose = int(prob * y.shape[0])
  flip_l = np.random.choice([i for i in range(y.shape[0])], size=n_choose)
  y[flip_l] = 1 - y[flip_l]
  return y

# %% [markdown]
# ### Modified Training Loop
#
# Incorporate the above mentioned suggestions in your training process. You don't have to apply all of them. See which combination works best for you. Mention the methods you made use of.

# %%
def gan_training_loop_mod(intervals=200):
    # Setup Models here
    discriminator = build_discriminator_mod()
    generator = build_generator_mod()
    dcgan = build_gan(generator,discriminator)

    X_train = load_data()
    total_size = X_train.shape[0]
    indices = np.arange(0,total_size ,BATCH_SIZE)
    all_disc_loss = []
    all_gen_loss = []
    if total_size % BATCH_SIZE:
        indices = indices[:-1]
    for e in range(EPOCHS):
        progress_bar = Progbar(target=len(indices))
        np.random.shuffle(indices)
        epoch_gen_loss = []
        epoch_disc_loss = []
        for i,index in enumerate(indices):
            training_samples = normalize(X_train[index:index+BATCH_SIZE])
            noise_samples  = sample_noise_mod()
            generated_imgs = generator.predict(noise_samples)

            labels_real = smooth_real_labels(np.ones((BATCH_SIZE,), dtype=int))
            labels_fake = smooth_fake_labels(np.zeros((BATCH_SIZE,), dtype=int))

            # labels_real = flip_labels(np.ones((BATCH_SIZE,), dtype=int))
            # labels_fake = flip_labels(np.zeros((BATCH_SIZE,), dtype=int))
            hist_disc_real = discriminator.train_on_batch(training_samples,labels_real)
            hist_disc_fake = discriminator.train_on_batch(generated_imgs,labels_fake)

            # Write your code here
            if not (e % intervals):
                save_samples(generated_imgs,e,save_at='samples_mod10')
              
            # If you are training the discriminator in two updates, uncomment this
            disc_loss = (hist_disc_fake[0] + hist_disc_real[0]) * 0.5
            epoch_disc_loss.append(disc_loss)

            for l in discriminator.layers:
              l.trainable = False

            noise_gen = sample_noise_mod()
            #labels_flip_gen = flip_labels(np.ones((BATCH_SIZE,), dtype=int))
            labels_real_gen = flip_labels((np.ones((BATCH_SIZE,), dtype=int)))
            hist_gen = dcgan.train_on_batch(noise_gen,labels_real_gen)

            for l in discriminator.layers:
              l.trainable = True
      
            gen_loss = hist_gen[0]
            epoch_gen_loss.append(gen_loss)
            
            progress_bar.update(i+1)
        if not (e%intervals):
            discriminator.save_weights(os.path.join(BASE_DIR,'discriminator_mod10'),True)
            generator.save_weights(os.path.join(BASE_DIR,'generator_mod10'),True)
            
        avg_epoch_disc_loss = np.array(epoch_disc_loss).mean()
        avg_epoch_gen_loss = np.array(epoch_gen_loss).mean()
        all_disc_loss.append(avg_epoch_disc_loss)
        all_gen_loss.append(avg_epoch_gen_loss)
        print("Epoch: %d | Discriminator Loss: %f | Generator Loss: %f" % (e+1,avg_epoch_disc_loss,avg_epoch_gen_loss))
    return all_disc_loss,all_gen_loss

# %%
all_disc_loss_mod,all_gen_loss_mod = gan_training_loop_mod()
# Out:
# /usr/local/lib/python3.6/dist-packages/keras/engine/training.py:297: UserWarning: Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
#   'Discrepancy between trainable weights and collected trainable'
# /usr/local/lib/python3.6/dist-packages/keras/engine/training.py:297: UserWarning: Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
#   'Discrepancy between trainable weights and collected trainable'
# 5/5 [==============================] - 9s 2s/step
# Epoch: 1 | Discriminator Loss: 1.161570 | Generator Loss: 0.818213
# 5/5 [==============================] - 3s 505ms/step
# Epoch: 2 | Discriminator Loss: 0.386577 | Generator Loss: 0.773653
# 5/5 [==============================] - 3s 503ms/step
# Epoch: 3 | Discriminator Loss: 0.337321 | Generator Loss: 0.596979
# 5/5 [==============================] - 3s 505ms/step
# Epoch: 4 | Discriminator Loss: 0.338743 | Generator Loss: 0.504791
# 5/5 [==============================] - 3s 507ms/step
# Epoch: 5 | Discriminator Loss: 0.331318 | Generator Loss: 0.491881
# 5/5 [==============================] - 3s 503ms/step
# Epoch: 6 | Discriminator Loss: 0.307627 | Generator Loss: 0.518088
# 5/5 [==============================] - 3s 508ms/step
# Epoch: 7 | Discriminator Loss: 0.317814 | Generator Loss: 0.499166
# 5/5 [==============================] - 3s 503ms/step
# Epoch: 8 | Discriminator Loss: 0.309123 | Generator Loss: 0.503271
# 5/5 [==============================] - 3s 508ms/step
# Epoch: 9 | Discriminator Loss: 0.333129 | Generator Loss: 0.569205
# 5/5 [==============================] - 3s 503ms/step
# Epoch: 10 | Discriminator Loss: 0.393737 | Generator Loss: 1.140653
# 5/5 [==============================] - 3s 505ms/step
# Epoch: 11 | Discriminator Loss: 0.576633 | Generator Loss: 1.215081
# 5/5 [==============================] - 3s 504ms/step
# Epoch: 12 | Discriminator Loss: 0.780820 | Generator Loss: 1.581227
# 5/5 [==============================] - 3s 506ms/step
# Epoch: 13 | Discriminator Loss: 1.455907 | Generator Loss: 1.240205
# 5/5 [==============================] - 3s 505ms/step
# Epoch: 14 | Discriminator Loss: 1.597698 | Generator Loss: 1.020771
# 5/5 [==============================] - 3s 506ms/step
# Epoch: 15 | Discriminator Loss: 0.978297 | Generator Loss: 1.451614
# 5/5 [==============================] - 3s 506ms/step
# Epoch: 16 | Discriminator Loss: 1.050576 | Generator Loss: 1.750588
# 5/5 [==============================] - 3s 504ms/step
# Epoch: 17 | Discriminator Loss: 1.592802 | Generator Loss: 1.335414
# 5/5 [==============================] - 3s 504ms/step
# Epoch: 18 | Discriminator Loss: 1.451995 | Generator Loss: 1.279063
# 5/5 [==============================] - 3s 503ms/step
# Epoch: 19 | Discriminator Loss: 1.377435 | Generator Loss: 1.283218
# 5/5 [==============================] - 3s 504ms/step
# Epoch: 20 | Discriminator Loss: 0.823878 | Generator Loss: 1.294651
# 5/5 [==============================] - 3s 508ms/step
# Epoch: 21 | Discriminator Loss: 0.654118 | Generator Loss: 1.266785
# 5/5 [==============================] - 3s 504ms/step
# Epoch: 22 | Discriminator Loss: 0.515721 | Generator Loss: 1.311697
# 5/5 [==============================] - 3s 503ms/step
# Epoch: 23 | Discriminator Loss: 0.506978 | Generator Loss: 1.106462
# 5/5 [==============================] - 3s 505ms/step
# Epoch: 24 | Discriminator Loss: 0.492264 | Generator Loss: 1.277030
# 5/5 [==============================] - 3s 505ms/step
# Epoch: 25 | Discriminator Loss: 0.453299 | Generator Loss: 1.350517
# 5/5 [==============================] - 3s 508ms/step
# Epoch: 26 | Discriminator Loss: 0.434888 | Generator Loss: 1.399075
# 5/5 [==============================] - 3s 506ms/step
# Epoch: 27 | Discriminator Loss: 0.413414 | Generator Loss: 1.692485
# 5/5 [==============================] - 3s 520ms/step
# Epoch: 28 | Discriminator Loss: 0.435528 | Generator Loss: 1.637742
# 5/5 [==============================] - 3s 515ms/step
# Epoch: 29 | Discriminator Loss: 0.410091 | Generator Loss: 1.429379
# 5/5 [==============================] - 3s 511ms/step
# Epoch: 30 | Discriminator Loss: 0.412131 | Generator Loss: 1.231396
# 5/5 [==============================] - 3s 509ms/step
# Epoch: 31 | Discriminator Loss: 0.402793 | Generator Loss: 1.270766
# 5/5 [==============================] - 3s 505ms/step
# Epoch: 32 | Discriminator Loss: 0.434272 | Generator Loss: 0.814967
# 5/5 [==============================] - 3s 510ms/step
# Epoch: 33 | Discriminator Loss: 0.451282 | Generator Loss: 0.984264
# 5/5 [==============================] - 3s 520ms/step
# Epoch: 34 | Discriminator Loss: 0.513011 | Generator Loss: 1.012790
# 5/5 [==============================] - 3s 516ms/step
# Epoch: 35 | Discriminator Loss: 0.848091 | Generator Loss: 0.933798
# 5/5 [==============================] - 3s 513ms/step
# Epoch: 36 | Discriminator Loss: 0.632144 | Generator Loss: 1.251289
# 5/5 [==============================] - 3s 513ms/step
# Epoch: 37 | Discriminator Loss: 0.448432 | Generator Loss: 0.940273
# 5/5 [==============================] - 3s 518ms/step
# Epoch: 38 | Discriminator Loss: 0.408205 | Generator Loss: 1.030859
# 5/5 [==============================] - 3s 520ms/step
# Epoch: 39 | Discriminator Loss: 0.446830 | Generator Loss: 0.863761
# 5/5 [==============================] - 3s 515ms/step
# Epoch: 40 | Discriminator Loss: 0.435352 | Generator Loss: 0.750387
# 5/5 [==============================] - 3s 518ms/step
# Epoch: 41 | Discriminator Loss: 0.420621 | Generator Loss: 0.637457
# 5/5 [==============================] - 3s 525ms/step
# Epoch: 42 | Discriminator Loss: 0.373037 | Generator Loss: 0.597044
# 5/5 [==============================] - 3s 518ms/step
# Epoch: 43 | Discriminator Loss: 0.357599 | Generator Loss: 0.514204
# 5/5 [==============================] - 3s 523ms/step
# Epoch: 44 | Discriminator Loss: 0.351911 | Generator Loss: 0.506178
# 5/5 [==============================] - 3s 521ms/step
# Epoch: 45 | Discriminator Loss: 0.361599 | Generator Loss: 0.511550
# 5/5 [==============================] - 3s 528ms/step
# Epoch: 46 | Discriminator Loss: 0.335399 | Generator Loss: 0.504673
# 5/5 [==============================] - 3s 523ms/step
# Epoch: 47 | Discriminator Loss: 0.342160 | Generator Loss: 0.505775
# 5/5 [==============================] - 3s 530ms/step
# Epoch: 48 | Discriminator Loss: 0.341042 | Generator Loss: 0.490848
# 5/5 [==============================] - 3s 525ms/step
# Epoch: 49 | Discriminator Loss: 0.343614 | Generator Loss: 0.507493
# 5/5 [==============================] - 3s 528ms/step
# Epoch: 50 | Discriminator Loss: 0.329977 | Generator Loss: 0.501853
# 5/5 [==============================] - 3s 529ms/step
# Epoch: 51 | Discriminator Loss: 0.342116 | Generator Loss: 0.511790
# 5/5 [==============================] - 3s 525ms/step
# Epoch: 52 | Discriminator Loss: 0.347094 | Generator Loss: 0.506499
# 5/5 [==============================] - 3s 528ms/step
# Epoch: 53 | Discriminator Loss: 0.349617 | Generator Loss: 0.521657
# 5/5 [==============================] - 3s 528ms/step
# Epoch: 54 | Discriminator Loss: 0.340195 | Generator Loss: 0.528423
# 5/5 [==============================] - 3s 521ms/step
# Epoch: 55 | Discriminator Loss: 0.333504 | Generator Loss: 0.518894
# 5/5 [==============================] - 3s 527ms/step
# Epoch: 56 | Discriminator Loss: 0.350519 | Generator Loss: 0.541315
# 5/5 [==============================] - 3s 523ms/step
# Epoch: 57 | Discriminator Loss: 0.369987 | Generator Loss: 0.614849
# 5/5 [==============================] - 3s 527ms/step
# Epoch: 58 | Discriminator Loss: 0.376191 | Generator Loss: 0.644924
# 5/5 [==============================] - 3s 520ms/step
# Epoch: 59 | Discriminator Loss: 0.381288 | Generator Loss: 0.709007
# 5/5 [==============================] - 3s 528ms/step
# Epoch: 60 | Discriminator Loss: 0.380637 | Generator Loss: 0.865608
# 5/5 [==============================] - 3s 520ms/step
# Epoch: 61 | Discriminator Loss: 0.401584 | Generator Loss: 1.204289
# 5/5 [==============================] - 3s 523ms/step
# Epoch: 62 | Discriminator Loss: 0.420231 | Generator Loss: 1.628000
# 5/5 [==============================] - 3s 522ms/step
# Epoch: 63 | Discriminator Loss: 0.487332 | Generator Loss: 1.841168
# 5/5 [==============================] - 3s 524ms/step
# Epoch: 64 | Discriminator Loss: 0.513621 | Generator Loss: 1.817041
# 5/5 [==============================] - 3s 524ms/step
# Epoch: 65 | Discriminator Loss: 0.464906 | Generator Loss: 1.615011
# 5/5 [==============================] - 3s 511ms/step
# Epoch: 66 | Discriminator Loss: 0.433229 | Generator Loss: 1.499486
# 5/5 [==============================] - 3s 517ms/step
# Epoch: 67 | Discriminator Loss: 0.395818 | Generator Loss: 1.540458
# 5/5 [==============================] - 3s 522ms/step
# Epoch: 68 | Discriminator Loss: 0.369894 | Generator Loss: 1.467068
# 5/5 [==============================] - 3s 515ms/step
# Epoch: 69 | Discriminator Loss: 0.384991 | Generator Loss: 1.372427
# 5/5 [==============================] - 3s 522ms/step
# Epoch: 70 | Discriminator Loss: 0.376051 | Generator Loss: 1.363876
# 5/5 [==============================] - 3s 520ms/step
# Epoch: 71 | Discriminator Loss: 0.392103 | Generator Loss: 1.355365
# 5/5 [==============================] - 3s 525ms/step
# Epoch: 72 | Discriminator Loss: 0.375399 | Generator Loss: 1.414960
# 5/5 [==============================] - 3s 522ms/step
# Epoch: 73 | Discriminator Loss: 0.356623 | Generator Loss: 1.569865
# 5/5 [==============================] - 3s 524ms/step
# Epoch: 74 | Discriminator Loss: 0.358735 | Generator Loss: 1.605904
# 5/5 [==============================] - 3s 523ms/step
# Epoch: 75 | Discriminator Loss: 0.340470 | Generator Loss: 2.180496
# 5/5 [==============================] - 3s 519ms/step
# Epoch: 76 | Discriminator Loss: 0.338763 | Generator Loss: 1.800060
# 5/5 [==============================] - 3s 526ms/step
# Epoch: 77 | Discriminator Loss: 0.337301 | Generator Loss: 1.450425
# 5/5 [==============================] - 3s 517ms/step
# Epoch: 78 | Discriminator Loss: 0.356764 | Generator Loss: 1.260684
# 5/5 [==============================] - 3s 529ms/step
# Epoch: 79 | Discriminator Loss: 0.327851 | Generator Loss: 1.149120
# 5/5 [==============================] - 3s 524ms/step
# Epoch: 80 | Discriminator Loss: 0.326181 | Generator Loss: 1.236521
# 5/5 [==============================] - 3s 525ms/step
# Epoch: 81 | Discriminator Loss: 0.335821 | Generator Loss: 1.229072
# 5/5 [==============================] - 3s 519ms/step
# Epoch: 82 | Discriminator Loss: 0.353915 | Generator Loss: 0.922814
# 5/5 [==============================] - 3s 527ms/step
# Epoch: 83 | Discriminator Loss: 0.337807 | Generator Loss: 1.026928
# 5/5 [==============================] - 3s 524ms/step
# Epoch: 84 | Discriminator Loss: 0.343240 | Generator Loss: 1.209660
# 5/5 [==============================] - 3s 527ms/step
# Epoch: 85 | Discriminator Loss: 0.340307 | Generator Loss: 1.240666
# 5/5 [==============================] - 3s 523ms/step
# Epoch: 86 | Discriminator Loss: 0.343071 | Generator Loss: 1.059170
# 5/5 [==============================] - 3s 525ms/step
# Epoch: 87 | Discriminator Loss: 0.370842 | Generator Loss: 1.481588
# 5/5 [==============================] - 3s 520ms/step
# Epoch: 88 | Discriminator Loss: 0.354498 | Generator Loss: 1.924483
# 5/5 [==============================] - 3s 527ms/step
# Epoch: 89 | Discriminator Loss: 0.366724 | Generator Loss: 1.883644
# 5/5 [==============================] - 3s 527ms/step
# Epoch: 90 | Discriminator Loss: 0.356786 | Generator Loss: 1.884110
# 5/5 [==============================] - 3s 523ms/step
# Epoch: 91 | Discriminator Loss: 0.345499 | Generator Loss: 1.647678
# 5/5 [==============================] - 3s 524ms/step
# Epoch: 92 | Discriminator Loss: 0.348908 | Generator Loss: 1.625806
# 5/5 [==============================] - 3s 525ms/step
# Epoch: 93 | Discriminator Loss: 0.364317 | Generator Loss: 1.709741
# 5/5 [==============================] - 3s 522ms/step
# Epoch: 94 | Discriminator Loss: 0.370168 | Generator Loss: 1.752814
# 5/5 [==============================] - 3s 522ms/step
# Epoch: 95 | Discriminator Loss: 0.366065 | Generator Loss: 1.838724
# 5/5 [==============================] - 3s 518ms/step
# Epoch: 96 | Discriminator Loss: 0.358392 | Generator Loss: 1.876349
# 5/5 [==============================] - 3s 527ms/step
# Epoch: 97 | Discriminator Loss: 0.338604 | Generator Loss: 1.659516
# 5/5 [==============================] - 3s 516ms/step
# Epoch: 98 | Discriminator Loss: 0.351089 | Generator Loss: 1.375243
# 5/5 [==============================] - 3s 521ms/step
# Epoch: 99 | Discriminator Loss: 0.342632 | Generator Loss: 1.049121
# 5/5 [==============================] - 3s 521ms/step
# Epoch: 100 | Discriminator Loss: 0.330294 | Generator Loss: 0.966854
# 5/5 [==============================] - 3s 514ms/step
# Epoch: 101 | Discriminator Loss: 0.344044 | Generator Loss: 0.984295
# 5/5 [==============================] - 3s 520ms/step
# Epoch: 102 | Discriminator Loss: 0.333818 | Generator Loss: 0.980672
# 5/5 [==============================] - 3s 519ms/step
# Epoch: 103 | Discriminator Loss: 0.344918 | Generator Loss: 1.044342
# 5/5 [==============================] - 3s 522ms/step
# Epoch: 104 | Discriminator Loss: 0.341228 | Generator Loss: 1.186137
# 5/5 [==============================] - 3s 525ms/step
# Epoch: 105 | Discriminator Loss: 0.339362 | Generator Loss: 1.263700
# 5/5 [==============================] - 3s 522ms/step
# Epoch: 106 | Discriminator Loss: 0.309261 | Generator Loss: 1.279431
# 5/5 [==============================] - 3s 527ms/step
# Epoch: 107 | Discriminator Loss: 0.348247 | Generator Loss: 1.298025
# 5/5 [==============================] - 3s 526ms/step
# Epoch: 108 | Discriminator Loss: 0.334170 | Generator Loss: 1.257107
# 5/5 [==============================] - 3s 526ms/step
# Epoch: 109 | Discriminator Loss: 0.334804 | Generator Loss: 1.312875
# 5/5 [==============================] - 3s 529ms/step
# Epoch: 110 | Discriminator Loss: 0.341966 | Generator Loss: 1.211182
# 5/5 [==============================] - 3s 526ms/step
# Epoch: 111 | Discriminator Loss: 0.350095 | Generator Loss: 1.168783
# 5/5 [==============================] - 3s 525ms/step
# Epoch: 112 | Discriminator Loss: 0.318669 | Generator Loss: 1.043058
# 5/5 [==============================] - 3s 514ms/step
# Epoch: 113 | Discriminator Loss: 0.339253 | Generator Loss: 0.894025
# 5/5 [==============================] - 3s 527ms/step
# Epoch: 114 | Discriminator Loss: 0.337275 | Generator Loss: 1.029152
# 5/5 [==============================] - 3s 517ms/step
# Epoch: 115 | Discriminator Loss: 0.321975 | Generator Loss: 1.075909
# 5/5 [==============================] - 3s 520ms/step
# Epoch: 116 | Discriminator Loss: 0.342519 | Generator Loss: 1.145374
# 5/5 [==============================] - 3s 525ms/step
# Epoch: 117 | Discriminator Loss: 0.346495 | Generator Loss: 1.111115
# 5/5 [==============================] - 3s 517ms/step
# Epoch: 118 | Discriminator Loss: 0.333732 | Generator Loss: 1.238812
# 5/5 [==============================] - 3s 529ms/step
# Epoch: 119 | Discriminator Loss: 0.358656 | Generator Loss: 1.293860
# 5/5 [==============================] - 3s 516ms/step
# Epoch: 120 | Discriminator Loss: 0.323925 | Generator Loss: 1.225679
# 5/5 [==============================] - 3s 529ms/step
# Epoch: 121 | Discriminator Loss: 0.322599 | Generator Loss: 1.163137
# 5/5 [==============================] - 3s 525ms/step
# Epoch: 122 | Discriminator Loss: 0.340812 | Generator Loss: 1.193187
# 5/5 [==============================] - 3s 526ms/step
# Epoch: 123 | Discriminator Loss: 0.327551 | Generator Loss: 1.238977
# 5/5 [==============================] - 3s 526ms/step
# Epoch: 124 | Discriminator Loss: 0.318770 | Generator Loss: 1.415570
# 5/5 [==============================] - 3s 527ms/step
# Epoch: 125 | Discriminator Loss: 0.318551 | Generator Loss: 1.391385
# 5/5 [==============================] - 3s 529ms/step
# Epoch: 126 | Discriminator Loss: 0.331629 | Generator Loss: 1.443616
# 5/5 [==============================] - 3s 526ms/step
# Epoch: 127 | Discriminator Loss: 0.312748 | Generator Loss: 1.626643
# 5/5 [==============================] - 3s 524ms/step
# Epoch: 128 | Discriminator Loss: 0.321490 | Generator Loss: 1.627277
# 5/5 [==============================] - 3s 519ms/step
# Epoch: 129 | Discriminator Loss: 0.346913 | Generator Loss: 1.479376
# 5/5 [==============================] - 3s 522ms/step
# Epoch: 130 | Discriminator Loss: 0.345643 | Generator Loss: 1.487026
# 5/5 [==============================] - 3s 520ms/step
# Epoch: 131 | Discriminator Loss: 0.322329 | Generator Loss: 1.657531
# 5/5 [==============================] - 3s 525ms/step
# Epoch: 132 | Discriminator Loss: 0.336972 | Generator Loss: 1.784149
# 5/5 [==============================] - 3s 516ms/step
# Epoch: 133 | Discriminator Loss: 0.307561 | Generator Loss: 1.695822
# 5/5 [==============================] - 3s 512ms/step
# Epoch: 134 | Discriminator Loss: 0.316026 | Generator Loss: 1.689393
# 5/5 [==============================] - 3s 519ms/step
# Epoch: 135 | Discriminator Loss: 0.334540 | Generator Loss: 1.703580
# 5/5 [==============================] - 3s 524ms/step
# Epoch: 136 | Discriminator Loss: 0.306248 | Generator Loss: 1.515178
# 5/5 [==============================] - 3s 526ms/step
# Epoch: 137 | Discriminator Loss: 0.322823 | Generator Loss: 1.413033
# 5/5 [==============================] - 3s 526ms/step
# Epoch: 138 | Discriminator Loss: 0.323805 | Generator Loss: 1.364540
# 5/5 [==============================] - 3s 527ms/step
# Epoch: 139 | Discriminator Loss: 0.328979 | Generator Loss: 1.348771
# 5/5 [==============================] - 3s 522ms/step
# Epoch: 140 | Discriminator Loss: 0.337457 | Generator Loss: 1.447103
# 5/5 [==============================] - 3s 530ms/step
# Epoch: 141 | Discriminator Loss: 0.313345 | Generator Loss: 1.517462
# 5/5 [==============================] - 3s 526ms/step
# Epoch: 142 | Discriminator Loss: 0.316485 | Generator Loss: 1.643456
# 5/5 [==============================] - 3s 524ms/step
# Epoch: 143 | Discriminator Loss: 0.325300 | Generator Loss: 1.525439
# 5/5 [==============================] - 3s 526ms/step
# Epoch: 144 | Discriminator Loss: 0.313068 | Generator Loss: 1.405692
# 5/5 [==============================] - 3s 526ms/step
# Epoch: 145 | Discriminator Loss: 0.315423 | Generator Loss: 1.284800
# 5/5 [==============================] - 3s 524ms/step
# Epoch: 146 | Discriminator Loss: 0.307281 | Generator Loss: 1.260036
# 5/5 [==============================] - 3s 520ms/step
# Epoch: 147 | Discriminator Loss: 0.334853 | Generator Loss: 1.402711
# 5/5 [==============================] - 3s 513ms/step
# Epoch: 148 | Discriminator Loss: 0.318978 | Generator Loss: 1.446285
# 5/5 [==============================] - 3s 519ms/step
# Epoch: 149 | Discriminator Loss: 0.321099 | Generator Loss: 1.399900
# 5/5 [==============================] - 3s 522ms/step
# Epoch: 150 | Discriminator Loss: 0.323358 | Generator Loss: 1.546990
# 5/5 [==============================] - 3s 523ms/step
# Epoch: 151 | Discriminator Loss: 0.319364 | Generator Loss: 1.519480
# 5/5 [==============================] - 3s 524ms/step
# Epoch: 152 | Discriminator Loss: 0.317748 | Generator Loss: 1.430210
# 5/5 [==============================] - 3s 521ms/step
# Epoch: 153 | Discriminator Loss: 0.316479 | Generator Loss: 1.384234
# 5/5 [==============================] - 3s 523ms/step
# Epoch: 154 | Discriminator Loss: 0.321960 | Generator Loss: 1.458492
# 5/5 [==============================] - 3s 518ms/step
# Epoch: 155 | Discriminator Loss: 0.309379 | Generator Loss: 1.541963
# 5/5 [==============================] - 3s 524ms/step
# Epoch: 156 | Discriminator Loss: 0.304745 | Generator Loss: 1.459552
# 5/5 [==============================] - 3s 524ms/step
# Epoch: 157 | Discriminator Loss: 0.296175 | Generator Loss: 1.494610
# 5/5 [==============================] - 3s 528ms/step
# Epoch: 158 | Discriminator Loss: 0.309584 | Generator Loss: 1.484871
# 5/5 [==============================] - 3s 528ms/step
# Epoch: 159 | Discriminator Loss: 0.331429 | Generator Loss: 1.484385
# 5/5 [==============================] - 3s 524ms/step
# Epoch: 160 | Discriminator Loss: 0.292910 | Generator Loss: 1.438676
# 5/5 [==============================] - 3s 523ms/step
# Epoch: 161 | Discriminator Loss: 0.317222 | Generator Loss: 1.466039
# 5/5 [==============================] - 3s 523ms/step
# Epoch: 162 | Discriminator Loss: 0.326590 | Generator Loss: 1.503811
# 5/5 [==============================] - 3s 514ms/step
# Epoch: 163 | Discriminator Loss: 0.314174 | Generator Loss: 1.548110
# 5/5 [==============================] - 3s 510ms/step
# Epoch: 164 | Discriminator Loss: 0.320122 | Generator Loss: 1.492634
# 5/5 [==============================] - 3s 523ms/step
# Epoch: 165 | Discriminator Loss: 0.313616 | Generator Loss: 1.523188
# 5/5 [==============================] - 3s 520ms/step
# Epoch: 166 | Discriminator Loss: 0.329378 | Generator Loss: 1.463150
# 5/5 [==============================] - 3s 520ms/step
# Epoch: 167 | Discriminator Loss: 0.309840 | Generator Loss: 1.493165
# 5/5 [==============================] - 3s 521ms/step
# Epoch: 168 | Discriminator Loss: 0.309868 | Generator Loss: 1.504430
# 5/5 [==============================] - 3s 519ms/step
# Epoch: 169 | Discriminator Loss: 0.317588 | Generator Loss: 1.460344
# 5/5 [==============================] - 3s 525ms/step
# Epoch: 170 | Discriminator Loss: 0.322711 | Generator Loss: 1.447214
# 5/5 [==============================] - 3s 523ms/step
# Epoch: 171 | Discriminator Loss: 0.318442 | Generator Loss: 1.479401
# 5/5 [==============================] - 3s 529ms/step
# Epoch: 172 | Discriminator Loss: 0.327537 | Generator Loss: 1.510124
# 5/5 [==============================] - 3s 525ms/step
# Epoch: 173 | Discriminator Loss: 0.315091 | Generator Loss: 1.544841
# 5/5 [==============================] - 3s 527ms/step
# Epoch: 174 | Discriminator Loss: 0.325158 | Generator Loss: 1.580907
# 5/5 [==============================] - 3s 527ms/step
# Epoch: 175 | Discriminator Loss: 0.311792 | Generator Loss: 1.475679
# 5/5 [==============================] - 3s 522ms/step
# Epoch: 176 | Discriminator Loss: 0.323731 | Generator Loss: 1.540096
# 5/5 [==============================] - 3s 530ms/step
# Epoch: 177 | Discriminator Loss: 0.305754 | Generator Loss: 1.591714
# 5/5 [==============================] - 3s 516ms/step
# Epoch: 178 | Discriminator Loss: 0.326879 | Generator Loss: 1.489270
# 5/5 [==============================] - 3s 518ms/step
# Epoch: 179 | Discriminator Loss: 0.320900 | Generator Loss: 1.512076
# 5/5 [==============================] - 3s 525ms/step
# Epoch: 180 | Discriminator Loss: 0.320573 | Generator Loss: 1.467659
# 5/5 [==============================] - 3s 515ms/step
# Epoch: 181 | Discriminator Loss: 0.315913 | Generator Loss: 1.620474
# 5/5 [==============================] - 3s 513ms/step
# Epoch: 182 | Discriminator Loss: 0.304842 | Generator Loss: 1.632133
# 5/5 [==============================] - 3s 520ms/step
# Epoch: 183 | Discriminator Loss: 0.325812 | Generator Loss: 1.530283
# 5/5 [==============================] - 3s 519ms/step
# Epoch: 184 | Discriminator Loss: 0.319530 | Generator Loss: 1.489954
# 5/5 [==============================] - 3s 520ms/step
# Epoch: 185 | Discriminator Loss: 0.325371 | Generator Loss: 1.476965
# 5/5 [==============================] - 3s 527ms/step
# Epoch: 186 | Discriminator Loss: 0.299455 | Generator Loss: 1.466253
# 5/5 [==============================] - 3s 522ms/step
# Epoch: 187 | Discriminator Loss: 0.330959 | Generator Loss: 1.477610
# 5/5 [==============================] - 3s 527ms/step
# Epoch: 188 | Discriminator Loss: 0.297753 | Generator Loss: 1.465747
# 5/5 [==============================] - 3s 522ms/step
# Epoch: 189 | Discriminator Loss: 0.322855 | Generator Loss: 1.498346
# 5/5 [==============================] - 3s 527ms/step
# Epoch: 190 | Discriminator Loss: 0.314531 | Generator Loss: 1.408073
# 5/5 [==============================] - 3s 530ms/step
# Epoch: 191 | Discriminator Loss: 0.324465 | Generator Loss: 1.438532
# 5/5 [==============================] - 3s 522ms/step
# Epoch: 192 | Discriminator Loss: 0.309253 | Generator Loss: 1.496422
# 5/5 [==============================] - 3s 526ms/step
# Epoch: 193 | Discriminator Loss: 0.331597 | Generator Loss: 1.496579
# 5/5 [==============================] - 3s 522ms/step
# Epoch: 194 | Discriminator Loss: 0.317337 | Generator Loss: 1.434836
# 5/5 [==============================] - 3s 528ms/step
# Epoch: 195 | Discriminator Loss: 0.319171 | Generator Loss: 1.455816
# 5/5 [==============================] - 3s 517ms/step
# Epoch: 196 | Discriminator Loss: 0.304589 | Generator Loss: 1.479355
# 5/5 [==============================] - 3s 514ms/step
# Epoch: 197 | Discriminator Loss: 0.311057 | Generator Loss: 1.419154
# 5/5 [==============================] - 3s 523ms/step
# Epoch: 198 | Discriminator Loss: 0.318215 | Generator Loss: 1.431954
# 5/5 [==============================] - 3s 519ms/step
# Epoch: 199 | Discriminator Loss: 0.319105 | Generator Loss: 1.503803
# 5/5 [==============================] - 3s 524ms/step
# Epoch: 200 | Discriminator Loss: 0.327709 | Generator Loss: 1.443510
# 5/5 [==============================] - 4s 711ms/step
# Epoch: 201 | Discriminator Loss: 0.314217 | Generator Loss: 1.447277
# 5/5 [==============================] - 3s 518ms/step
# Epoch: 202 | Discriminator Loss: 0.321608 | Generator Loss: 1.376698
# 5/5 [==============================] - 3s 521ms/step
# Epoch: 203 | Discriminator Loss: 0.309873 | Generator Loss: 1.399035
# 5/5 [==============================] - 3s 520ms/step
# Epoch: 204 | Discriminator Loss: 0.307945 | Generator Loss: 1.461850
# 5/5 [==============================] - 3s 518ms/step
# Epoch: 205 | Discriminator Loss: 0.307738 | Generator Loss: 1.432670
# 5/5 [==============================] - 3s 525ms/step
# Epoch: 206 | Discriminator Loss: 0.311030 | Generator Loss: 1.384105
# 5/5 [==============================] - 3s 527ms/step
# Epoch: 207 | Discriminator Loss: 0.311641 | Generator Loss: 1.377743
# 5/5 [==============================] - 3s 526ms/step
# Epoch: 208 | Discriminator Loss: 0.326604 | Generator Loss: 1.394824
# 5/5 [==============================] - 3s 525ms/step
# Epoch: 209 | Discriminator Loss: 0.301647 | Generator Loss: 1.417973
# 5/5 [==============================] - 3s 527ms/step
# Epoch: 210 | Discriminator Loss: 0.306236 | Generator Loss: 1.468266
# 5/5 [==============================] - 3s 523ms/step
# Epoch: 211 | Discriminator Loss: 0.320286 | Generator Loss: 1.429529
# 5/5 [==============================] - 3s 523ms/step
# Epoch: 212 | Discriminator Loss: 0.314026 | Generator Loss: 1.443948
# 5/5 [==============================] - 3s 522ms/step
# Epoch: 213 | Discriminator Loss: 0.310192 | Generator Loss: 1.480003
# 5/5 [==============================] - 3s 528ms/step
# Epoch: 214 | Discriminator Loss: 0.301357 | Generator Loss: 1.518435
# 5/5 [==============================] - 3s 524ms/step
# Epoch: 215 | Discriminator Loss: 0.307896 | Generator Loss: 1.487761
# 5/5 [==============================] - 3s 525ms/step
# Epoch: 216 | Discriminator Loss: 0.332080 | Generator Loss: 1.478254
# 5/5 [==============================] - 3s 522ms/step
# Epoch: 217 | Discriminator Loss: 0.320167 | Generator Loss: 1.439838
# 5/5 [==============================] - 3s 525ms/step
# Epoch: 218 | Discriminator Loss: 0.306192 | Generator Loss: 1.462489
# 5/5 [==============================] - 3s 523ms/step
# Epoch: 219 | Discriminator Loss: 0.323753 | Generator Loss: 1.395978
# 5/5 [==============================] - 3s 521ms/step
# Epoch: 220 | Discriminator Loss: 0.298720 | Generator Loss: 1.386554
# 5/5 [==============================] - 3s 528ms/step
# Epoch: 221 | Discriminator Loss: 0.323345 | Generator Loss: 1.453687
# 5/5 [==============================] - 3s 520ms/step
# Epoch: 222 | Discriminator Loss: 0.319542 | Generator Loss: 1.454590
# 5/5 [==============================] - 3s 524ms/step
# Epoch: 223 | Discriminator Loss: 0.301720 | Generator Loss: 1.480232
# 5/5 [==============================] - 3s 524ms/step
# Epoch: 224 | Discriminator Loss: 0.307467 | Generator Loss: 1.488684
# 5/5 [==============================] - 3s 517ms/step
# Epoch: 225 | Discriminator Loss: 0.316390 | Generator Loss: 1.457645
# 5/5 [==============================] - 3s 523ms/step
# Epoch: 226 | Discriminator Loss: 0.314522 | Generator Loss: 1.457752
# 5/5 [==============================] - 3s 518ms/step
# Epoch: 227 | Discriminator Loss: 0.323017 | Generator Loss: 1.468494
# 5/5 [==============================] - 3s 526ms/step
# Epoch: 228 | Discriminator Loss: 0.312557 | Generator Loss: 1.444812
# 5/5 [==============================] - 3s 517ms/step
# Epoch: 229 | Discriminator Loss: 0.313053 | Generator Loss: 1.389408
# 5/5 [==============================] - 3s 520ms/step
# Epoch: 230 | Discriminator Loss: 0.320281 | Generator Loss: 1.441689
# 5/5 [==============================] - 3s 525ms/step
# Epoch: 231 | Discriminator Loss: 0.310633 | Generator Loss: 1.379418
# 5/5 [==============================] - 3s 523ms/step
# Epoch: 232 | Discriminator Loss: 0.304510 | Generator Loss: 1.318204
# 5/5 [==============================] - 3s 522ms/step
# Epoch: 233 | Discriminator Loss: 0.321341 | Generator Loss: 1.323380
# 5/5 [==============================] - 3s 521ms/step
# Epoch: 234 | Discriminator Loss: 0.309967 | Generator Loss: 1.312020
# 5/5 [==============================] - 3s 525ms/step
# Epoch: 235 | Discriminator Loss: 0.301103 | Generator Loss: 1.346055
# 5/5 [==============================] - 3s 522ms/step
# Epoch: 236 | Discriminator Loss: 0.323773 | Generator Loss: 1.378858
# 5/5 [==============================] - 3s 526ms/step
# Epoch: 237 | Discriminator Loss: 0.317232 | Generator Loss: 1.370249
# 5/5 [==============================] - 3s 524ms/step
# Epoch: 238 | Discriminator Loss: 0.291138 | Generator Loss: 1.385343
# 5/5 [==============================] - 3s 528ms/step
# Epoch: 239 | Discriminator Loss: 0.318564 | Generator Loss: 1.390633
# 5/5 [==============================] - 3s 517ms/step
# Epoch: 240 | Discriminator Loss: 0.305761 | Generator Loss: 1.359126
# 5/5 [==============================] - 3s 525ms/step
# Epoch: 241 | Discriminator Loss: 0.311888 | Generator Loss: 1.386195
# 5/5 [==============================] - 3s 517ms/step
# Epoch: 242 | Discriminator Loss: 0.301119 | Generator Loss: 1.469465
# 5/5 [==============================] - 3s 517ms/step
# Epoch: 243 | Discriminator Loss: 0.317464 | Generator Loss: 1.447153
# 5/5 [==============================] - 3s 527ms/step
# Epoch: 244 | Discriminator Loss: 0.313780 | Generator Loss: 1.398808
# 5/5 [==============================] - 3s 523ms/step
# Epoch: 245 | Discriminator Loss: 0.330442 | Generator Loss: 1.403358
# 5/5 [==============================] - 3s 524ms/step
# Epoch: 246 | Discriminator Loss: 0.316940 | Generator Loss: 1.273764
# 5/5 [==============================] - 3s 526ms/step
# Epoch: 247 | Discriminator Loss: 0.306861 | Generator Loss: 1.356316
# 5/5 [==============================] - 3s 524ms/step
# Epoch: 248 | Discriminator Loss: 0.330119 | Generator Loss: 1.344197
# 5/5 [==============================] - 3s 522ms/step
# Epoch: 249 | Discriminator Loss: 0.323323 | Generator Loss: 1.360718
# 5/5 [==============================] - 3s 527ms/step
# Epoch: 250 | Discriminator Loss: 0.310484 | Generator Loss: 1.369700
# 5/5 [==============================] - 3s 523ms/step
# Epoch: 251 | Discriminator Loss: 0.310598 | Generator Loss: 1.425828
# 5/5 [==============================] - 3s 524ms/step
# Epoch: 252 | Discriminator Loss: 0.335101 | Generator Loss: 1.402524
# 5/5 [==============================] - 3s 525ms/step
# Epoch: 253 | Discriminator Loss: 0.319728 | Generator Loss: 1.506995
# 5/5 [==============================] - 3s 525ms/step
# Epoch: 254 | Discriminator Loss: 0.315173 | Generator Loss: 1.438481
# 5/5 [==============================] - 3s 527ms/step
# Epoch: 255 | Discriminator Loss: 0.306885 | Generator Loss: 1.471724
# 5/5 [==============================] - 3s 521ms/step
# Epoch: 256 | Discriminator Loss: 0.310066 | Generator Loss: 1.502780
# 5/5 [==============================] - 3s 530ms/step
# Epoch: 257 | Discriminator Loss: 0.314086 | Generator Loss: 1.436228
# 5/5 [==============================] - 3s 522ms/step
# Epoch: 258 | Discriminator Loss: 0.308825 | Generator Loss: 1.429156
# 5/5 [==============================] - 3s 527ms/step
# Epoch: 259 | Discriminator Loss: 0.323034 | Generator Loss: 1.466325
# 5/5 [==============================] - 3s 524ms/step
# Epoch: 260 | Discriminator Loss: 0.326792 | Generator Loss: 1.462480
# 5/5 [==============================] - 3s 523ms/step
# Epoch: 261 | Discriminator Loss: 0.323053 | Generator Loss: 1.527274
# 5/5 [==============================] - 3s 530ms/step
# Epoch: 262 | Discriminator Loss: 0.322069 | Generator Loss: 1.521523
# 5/5 [==============================] - 3s 521ms/step
# Epoch: 263 | Discriminator Loss: 0.311751 | Generator Loss: 1.477925
# 5/5 [==============================] - 3s 529ms/step
# Epoch: 264 | Discriminator Loss: 0.307847 | Generator Loss: 1.531201
# 5/5 [==============================] - 3s 526ms/step
# Epoch: 265 | Discriminator Loss: 0.303987 | Generator Loss: 1.447345
# 5/5 [==============================] - 3s 525ms/step
# Epoch: 266 | Discriminator Loss: 0.288887 | Generator Loss: 1.397613
# 5/5 [==============================] - 3s 520ms/step
# Epoch: 267 | Discriminator Loss: 0.305448 | Generator Loss: 1.335335
# 5/5 [==============================] - 3s 530ms/step
# Epoch: 268 | Discriminator Loss: 0.313797 | Generator Loss: 1.235620
# 5/5 [==============================] - 3s 525ms/step
# Epoch: 269 | Discriminator Loss: 0.336111 | Generator Loss: 1.333039
# 5/5 [==============================] - 3s 522ms/step
# Epoch: 270 | Discriminator Loss: 0.349633 | Generator Loss: 1.292918
# 5/5 [==============================] - 3s 530ms/step
# Epoch: 271 | Discriminator Loss: 0.376415 | Generator Loss: 1.669070
# 5/5 [==============================] - 3s 519ms/step
# Epoch: 272 | Discriminator Loss: 0.332631 | Generator Loss: 1.304671
# 5/5 [==============================] - 3s 527ms/step
# Epoch: 273 | Discriminator Loss: 0.312904 | Generator Loss: 1.255136
# 5/5 [==============================] - 3s 523ms/step
# Epoch: 274 | Discriminator Loss: 0.323169 | Generator Loss: 1.353694
# 5/5 [==============================] - 3s 527ms/step
# Epoch: 275 | Discriminator Loss: 0.321762 | Generator Loss: 1.334353
# 5/5 [==============================] - 3s 520ms/step
# Epoch: 276 | Discriminator Loss: 0.314034 | Generator Loss: 1.300584
# 5/5 [==============================] - 3s 524ms/step
# Epoch: 277 | Discriminator Loss: 0.318065 | Generator Loss: 1.269957
# 5/5 [==============================] - 3s 523ms/step
# Epoch: 278 | Discriminator Loss: 0.316150 | Generator Loss: 1.280142
# 5/5 [==============================] - 3s 526ms/step
# Epoch: 279 | Discriminator Loss: 0.291874 | Generator Loss: 1.219285
# 5/5 [==============================] - 3s 526ms/step
# Epoch: 280 | Discriminator Loss: 0.321280 | Generator Loss: 1.221435
# 5/5 [==============================] - 3s 531ms/step
# Epoch: 281 | Discriminator Loss: 0.330432 | Generator Loss: 1.165335
# 5/5 [==============================] - 3s 515ms/step
# Epoch: 282 | Discriminator Loss: 0.325689 | Generator Loss: 1.232535
# 5/5 [==============================] - 3s 527ms/step
# Epoch: 283 | Discriminator Loss: 0.331690 | Generator Loss: 1.082814
# 5/5 [==============================] - 3s 523ms/step
# Epoch: 284 | Discriminator Loss: 0.312427 | Generator Loss: 1.077034
# 5/5 [==============================] - 3s 525ms/step
# Epoch: 285 | Discriminator Loss: 0.322574 | Generator Loss: 1.160249
# 5/5 [==============================] - 3s 521ms/step
# Epoch: 286 | Discriminator Loss: 0.327743 | Generator Loss: 1.122957
# 5/5 [==============================] - 3s 526ms/step
# Epoch: 287 | Discriminator Loss: 0.333464 | Generator Loss: 1.188442
# 5/5 [==============================] - 3s 521ms/step
# Epoch: 288 | Discriminator Loss: 0.331246 | Generator Loss: 1.190201
# 5/5 [==============================] - 3s 528ms/step
# Epoch: 289 | Discriminator Loss: 0.315276 | Generator Loss: 1.151085
# 5/5 [==============================] - 3s 520ms/step
# Epoch: 290 | Discriminator Loss: 0.312131 | Generator Loss: 1.204231
# 5/5 [==============================] - 3s 529ms/step
# Epoch: 291 | Discriminator Loss: 0.322100 | Generator Loss: 1.147504
# 5/5 [==============================] - 3s 519ms/step
# Epoch: 292 | Discriminator Loss: 0.320010 | Generator Loss: 1.118852
# 5/5 [==============================] - 3s 525ms/step
# Epoch: 293 | Discriminator Loss: 0.331414 | Generator Loss: 1.083232
# 5/5 [==============================] - 3s 517ms/step
# Epoch: 294 | Discriminator Loss: 0.316245 | Generator Loss: 1.101353
# 5/5 [==============================] - 3s 526ms/step
# Epoch: 295 | Discriminator Loss: 0.314710 | Generator Loss: 1.099698
# 5/5 [==============================] - 3s 522ms/step
# Epoch: 296 | Discriminator Loss: 0.330865 | Generator Loss: 1.094734
# 5/5 [==============================] - 3s 522ms/step
# Epoch: 297 | Discriminator Loss: 0.315300 | Generator Loss: 1.084613
# 5/5 [==============================] - 3s 526ms/step
# Epoch: 298 | Discriminator Loss: 0.327029 | Generator Loss: 1.119434
# 5/5 [==============================] - 3s 517ms/step
# Epoch: 299 | Discriminator Loss: 0.317493 | Generator Loss: 1.050641
# 5/5 [==============================] - 3s 525ms/step
# Epoch: 300 | Discriminator Loss: 0.315817 | Generator Loss: 1.096305
# 5/5 [==============================] - 3s 520ms/step
# Epoch: 301 | Discriminator Loss: 0.328222 | Generator Loss: 1.032732
# 5/5 [==============================] - 3s 523ms/step
# Epoch: 302 | Discriminator Loss: 0.325973 | Generator Loss: 1.077713
# 5/5 [==============================] - 3s 521ms/step
# Epoch: 303 | Discriminator Loss: 0.323842 | Generator Loss: 1.125670
# 5/5 [==============================] - 3s 527ms/step
# Epoch: 304 | Discriminator Loss: 0.333701 | Generator Loss: 1.016626
# 5/5 [==============================] - 3s 519ms/step
# Epoch: 305 | Discriminator Loss: 0.325237 | Generator Loss: 0.896158
# 5/5 [==============================] - 3s 521ms/step
# Epoch: 306 | Discriminator Loss: 0.331964 | Generator Loss: 0.813333
# 5/5 [==============================] - 3s 527ms/step
# Epoch: 307 | Discriminator Loss: 0.337785 | Generator Loss: 0.897620
# 5/5 [==============================] - 3s 518ms/step
# Epoch: 308 | Discriminator Loss: 0.323121 | Generator Loss: 0.864770
# 5/5 [==============================] - 3s 525ms/step
# Epoch: 309 | Discriminator Loss: 0.311627 | Generator Loss: 0.976086
# 5/5 [==============================] - 3s 518ms/step
# Epoch: 310 | Discriminator Loss: 0.326050 | Generator Loss: 0.920438
# 5/5 [==============================] - 3s 517ms/step
# Epoch: 311 | Discriminator Loss: 0.330960 | Generator Loss: 0.959962
# 5/5 [==============================] - 3s 525ms/step
# Epoch: 312 | Discriminator Loss: 0.321295 | Generator Loss: 0.863557
# 5/5 [==============================] - 3s 520ms/step
# Epoch: 313 | Discriminator Loss: 0.333803 | Generator Loss: 1.016937
# 5/5 [==============================] - 3s 526ms/step
# Epoch: 314 | Discriminator Loss: 0.348724 | Generator Loss: 1.050269
# 5/5 [==============================] - 3s 515ms/step
# Epoch: 315 | Discriminator Loss: 0.331905 | Generator Loss: 1.091231
# 5/5 [==============================] - 3s 526ms/step
# Epoch: 316 | Discriminator Loss: 0.315220 | Generator Loss: 1.176482
# 5/5 [==============================] - 3s 517ms/step
# Epoch: 317 | Discriminator Loss: 0.330803 | Generator Loss: 1.164484
# 5/5 [==============================] - 3s 525ms/step
# Epoch: 318 | Discriminator Loss: 0.324961 | Generator Loss: 1.203963
# 5/5 [==============================] - 3s 525ms/step
# Epoch: 319 | Discriminator Loss: 0.308147 | Generator Loss: 1.165351
# 5/5 [==============================] - 3s 527ms/step
# Epoch: 320 | Discriminator Loss: 0.336874 | Generator Loss: 1.192213
# 5/5 [==============================] - 3s 521ms/step
# Epoch: 321 | Discriminator Loss: 0.330043 | Generator Loss: 1.222229
# 5/5 [==============================] - 3s 522ms/step
# Epoch: 322 | Discriminator Loss: 0.329297 | Generator Loss: 1.228258
# 5/5 [==============================] - 3s 521ms/step
# Epoch: 323 | Discriminator Loss: 0.334241 | Generator Loss: 1.218160
# 5/5 [==============================] - 3s 520ms/step
# Epoch: 324 | Discriminator Loss: 0.336910 | Generator Loss: 1.206293
# 5/5 [==============================] - 3s 522ms/step
# Epoch: 325 | Discriminator Loss: 0.346460 | Generator Loss: 1.173160
# 5/5 [==============================] - 3s 522ms/step
# Epoch: 326 | Discriminator Loss: 0.345665 | Generator Loss: 1.244958
# 5/5 [==============================] - 3s 526ms/step
# Epoch: 327 | Discriminator Loss: 0.356615 | Generator Loss: 1.283686
# 5/5 [==============================] - 3s 522ms/step
# Epoch: 328 | Discriminator Loss: 0.356082 | Generator Loss: 1.191265
# 5/5 [==============================] - 3s 525ms/step
# Epoch: 329 | Discriminator Loss: 0.365585 | Generator Loss: 1.109174
# 5/5 [==============================] - 3s 521ms/step
# Epoch: 330 | Discriminator Loss: 0.408088 | Generator Loss: 1.316413
# 5/5 [==============================] - 3s 524ms/step
# Epoch: 331 | Discriminator Loss: 0.345706 | Generator Loss: 1.196944
# 5/5 [==============================] - 3s 518ms/step
# Epoch: 332 | Discriminator Loss: 0.343886 | Generator Loss: 0.945554
# 5/5 [==============================] - 3s 523ms/step
# Epoch: 333 | Discriminator Loss: 0.347788 | Generator Loss: 0.752403
# 5/5 [==============================] - 3s 520ms/step
# Epoch: 334 | Discriminator Loss: 0.372066 | Generator Loss: 0.707725
# 5/5 [==============================] - 3s 517ms/step
# Epoch: 335 | Discriminator Loss: 0.370967 | Generator Loss: 0.642840
# 5/5 [==============================] - 3s 524ms/step
# Epoch: 336 | Discriminator Loss: 0.341603 | Generator Loss: 0.586307
# 5/5 [==============================] - 3s 522ms/step
# Epoch: 337 | Discriminator Loss: 0.361598 | Generator Loss: 0.685445
# 5/5 [==============================] - 3s 527ms/step
# Epoch: 338 | Discriminator Loss: 0.358995 | Generator Loss: 0.650384
# 5/5 [==============================] - 3s 519ms/step
# Epoch: 339 | Discriminator Loss: 0.340524 | Generator Loss: 0.774507
# 5/5 [==============================] - 3s 528ms/step
# Epoch: 340 | Discriminator Loss: 0.333597 | Generator Loss: 0.849665
# 5/5 [==============================] - 3s 520ms/step
# Epoch: 341 | Discriminator Loss: 0.366412 | Generator Loss: 0.949531
# 5/5 [==============================] - 3s 525ms/step
# Epoch: 342 | Discriminator Loss: 0.366610 | Generator Loss: 1.172371
# 5/5 [==============================] - 3s 525ms/step
# Epoch: 343 | Discriminator Loss: 0.384322 | Generator Loss: 1.209302
# 5/5 [==============================] - 3s 528ms/step
# Epoch: 344 | Discriminator Loss: 0.370445 | Generator Loss: 1.324264
# 5/5 [==============================] - 3s 523ms/step
# Epoch: 345 | Discriminator Loss: 0.400584 | Generator Loss: 1.019687
# 5/5 [==============================] - 3s 528ms/step
# Epoch: 346 | Discriminator Loss: 0.414756 | Generator Loss: 0.877040
# 5/5 [==============================] - 3s 516ms/step
# Epoch: 347 | Discriminator Loss: 0.349211 | Generator Loss: 1.132832
# 5/5 [==============================] - 3s 527ms/step
# Epoch: 348 | Discriminator Loss: 0.371267 | Generator Loss: 1.111221
# 5/5 [==============================] - 3s 518ms/step
# Epoch: 349 | Discriminator Loss: 0.360405 | Generator Loss: 1.531743
# 5/5 [==============================] - 3s 514ms/step
# Epoch: 350 | Discriminator Loss: 0.379553 | Generator Loss: 1.661158
# 5/5 [==============================] - 3s 525ms/step
# Epoch: 351 | Discriminator Loss: 0.322228 | Generator Loss: 1.485763
# 5/5 [==============================] - 3s 523ms/step
# Epoch: 352 | Discriminator Loss: 0.357433 | Generator Loss: 1.216861
# 5/5 [==============================] - 3s 527ms/step
# Epoch: 353 | Discriminator Loss: 0.352559 | Generator Loss: 1.048617
# 5/5 [==============================] - 3s 521ms/step
# Epoch: 354 | Discriminator Loss: 0.327015 | Generator Loss: 1.040624
# 5/5 [==============================] - 3s 526ms/step
# Epoch: 355 | Discriminator Loss: 0.325795 | Generator Loss: 0.841958
# 5/5 [==============================] - 3s 518ms/step
# Epoch: 356 | Discriminator Loss: 0.334742 | Generator Loss: 1.000709
# 5/5 [==============================] - 3s 523ms/step
# Epoch: 357 | Discriminator Loss: 0.339389 | Generator Loss: 1.229660
# 5/5 [==============================] - 3s 521ms/step
# Epoch: 358 | Discriminator Loss: 0.312923 | Generator Loss: 1.974798
# 5/5 [==============================] - 3s 525ms/step
# Epoch: 359 | Discriminator Loss: 0.336995 | Generator Loss: 2.639840
# 5/5 [==============================] - 3s 522ms/step
# Epoch: 360 | Discriminator Loss: 0.354750 | Generator Loss: 2.798532
# 5/5 [==============================] - 3s 514ms/step
# Epoch: 361 | Discriminator Loss: 0.336519 | Generator Loss: 2.828081
# 5/5 [==============================] - 3s 515ms/step
# Epoch: 362 | Discriminator Loss: 0.329536 | Generator Loss: 2.361686
# 5/5 [==============================] - 3s 524ms/step
# Epoch: 363 | Discriminator Loss: 0.329422 | Generator Loss: 1.754061
# 5/5 [==============================] - 3s 517ms/step
# Epoch: 364 | Discriminator Loss: 0.325849 | Generator Loss: 1.188415
# 5/5 [==============================] - 3s 526ms/step
# Epoch: 365 | Discriminator Loss: 0.332701 | Generator Loss: 0.853558
# 5/5 [==============================] - 3s 518ms/step
# Epoch: 366 | Discriminator Loss: 0.351514 | Generator Loss: 0.681273
# 5/5 [==============================] - 3s 519ms/step
# Epoch: 367 | Discriminator Loss: 0.340440 | Generator Loss: 0.721455
# 5/5 [==============================] - 3s 526ms/step
# Epoch: 368 | Discriminator Loss: 0.363133 | Generator Loss: 0.817688
# 5/5 [==============================] - 3s 514ms/step
# Epoch: 369 | Discriminator Loss: 0.339622 | Generator Loss: 1.071247
# 5/5 [==============================] - 3s 527ms/step
# Epoch: 370 | Discriminator Loss: 0.329760 | Generator Loss: 1.176193
# 5/5 [==============================] - 3s 518ms/step
# Epoch: 371 | Discriminator Loss: 0.326463 | Generator Loss: 1.277100
# 5/5 [==============================] - 3s 524ms/step
# Epoch: 372 | Discriminator Loss: 0.328295 | Generator Loss: 1.337121
# 5/5 [==============================] - 3s 525ms/step
# Epoch: 373 | Discriminator Loss: 0.325770 | Generator Loss: 1.379724
# 5/5 [==============================] - 3s 524ms/step
# Epoch: 374 | Discriminator Loss: 0.333065 | Generator Loss: 1.563056
# 5/5 [==============================] - 3s 521ms/step
# Epoch: 375 | Discriminator Loss: 0.325255 | Generator Loss: 1.405241
# 5/5 [==============================] - 3s 526ms/step
# Epoch: 376 | Discriminator Loss: 0.322335 | Generator Loss: 1.354974
# 5/5 [==============================] - 3s 521ms/step
# Epoch: 377 | Discriminator Loss: 0.353250 | Generator Loss: 1.123892
# 5/5 [==============================] - 3s 524ms/step
# Epoch: 378 | Discriminator Loss: 0.361632 | Generator Loss: 0.943306
# 5/5 [==============================] - 3s 522ms/step
# Epoch: 379 | Discriminator Loss: 0.343668 | Generator Loss: 0.714513
# 5/5 [==============================] - 3s 515ms/step
# Epoch: 380 | Discriminator Loss: 0.333492 | Generator Loss: 0.743461
# 5/5 [==============================] - 3s 521ms/step
# Epoch: 381 | Discriminator Loss: 0.349966 | Generator Loss: 0.969065
# 5/5 [==============================] - 3s 523ms/step
# Epoch: 382 | Discriminator Loss: 0.334483 | Generator Loss: 0.876770
# 5/5 [==============================] - 3s 511ms/step
# Epoch: 383 | Discriminator Loss: 0.306550 | Generator Loss: 0.962199
# 5/5 [==============================] - 3s 525ms/step
# Epoch: 384 | Discriminator Loss: 0.313208 | Generator Loss: 1.036136
# 5/5 [==============================] - 3s 520ms/step
# Epoch: 385 | Discriminator Loss: 0.329007 | Generator Loss: 1.067153
# 5/5 [==============================] - 3s 523ms/step
# Epoch: 386 | Discriminator Loss: 0.336024 | Generator Loss: 1.071748
# 5/5 [==============================] - 3s 519ms/step
# Epoch: 387 | Discriminator Loss: 0.331988 | Generator Loss: 1.162646
# 5/5 [==============================] - 3s 517ms/step
# Epoch: 388 | Discriminator Loss: 0.328811 | Generator Loss: 1.698103
# 5/5 [==============================] - 3s 521ms/step
# Epoch: 389 | Discriminator Loss: 0.350691 | Generator Loss: 1.698520
# 5/5 [==============================] - 3s 524ms/step
# ...
# 5/5 [==============================] - 3s 520ms/step
# Epoch: 1419 | Discriminator Loss: 0.366150 | Generator Loss: 1.082389
# 5/5 [==============================] - 3s 528ms/step
# Epoch: 1420 | Discriminator Loss: 0.347418 | Generator Loss: 0.902641
# 5/5 [==============================] - 3s 518ms/step
# Epoch: 1421 | Discriminator Loss: 0.330844 | Generator Loss: 0.819295
# 5/5 [==============================] - 3s 521ms/step
# Epoch: 1422 | Discriminator Loss: 0.328450 | Generator Loss: 0.761915
# 5/5 [==============================] - 3s 524ms/step
# Epoch: 1423 | Discriminator Loss: 0.308480 | Generator Loss: 0.613019
# 5/5 [==============================] - 3s 516ms/step
# Epoch: 1424 | Discriminator Loss: 0.332577 | Generator Loss: 0.571710
# 5/5 [==============================] - 3s 524ms/step
# Epoch: 1425 | Discriminator Loss: 0.318667 | Generator Loss: 0.762483
# 5/5 [==============================] - 3s 518ms/step
# Epoch: 1426 | Discriminator Loss: 0.321720 | Generator Loss: 1.272891
# 5/5 [==============================] - 3s 522ms/step
# Epoch: 1427 | Discriminator Loss: 0.338527 | Generator Loss: 1.582797
# 5/5 [==============================] - 3s 517ms/step
# Epoch: 1428 | Discriminator Loss: 0.325519 | Generator Loss: 1.333403
# 5/5 [==============================] - 3s 514ms/step
# Epoch: 1429 | Discriminator Loss: 0.338186 | Generator Loss: 0.679095
# 5/5 [==============================] - 3s 524ms/step
# Epoch: 1430 | Discriminator Loss: 0.336057 | Generator Loss: 0.528465
# 5/5 [==============================] - 3s 518ms/step
# Epoch: 1431 | Discriminator Loss: 0.303100 | Generator Loss: 0.518851
# 5/5 [==============================] - 3s 523ms/step
# Epoch: 1432 | Discriminator Loss: 0.320274 | Generator Loss: 0.505920
# 5/5 [==============================] - 3s 520ms/step
# Epoch: 1433 | Discriminator Loss: 0.330012 | Generator Loss: 0.523544
# 5/5 [==============================] - 3s 518ms/step
# Epoch: 1434 | Discriminator Loss: 0.316039 | Generator Loss: 0.601543
# 5/5 [==============================] - 3s 527ms/step
# Epoch: 1435 | Discriminator Loss: 0.321505 | Generator Loss: 0.697807
# 5/5 [==============================] - 3s 519ms/step
# Epoch: 1436 | Discriminator Loss: 0.332038 | Generator Loss: 0.786998
# 5/5 [==============================] - 3s 529ms/step
# Epoch: 1437 | Discriminator Loss: 0.328173 | Generator Loss: 0.879754
# 5/5 [==============================] - 3s 516ms/step
# Epoch: 1438 | Discriminator Loss: 0.332050 | Generator Loss: 0.825930
# 5/5 [==============================] - 3s 525ms/step
# Epoch: 1439 | Discriminator Loss: 0.322991 | Generator Loss: 0.773850
# 5/5 [==============================] - 3s 519ms/step
# Epoch: 1440 | Discriminator Loss: 0.327247 | Generator Loss: 0.895226
# 5/5 [==============================] - 3s 525ms/step
# Epoch: 1441 | Discriminator Loss: 0.358113 | Generator Loss: 1.233394
# 5/5 [==============================] - 3s 519ms/step
# Epoch: 1442 | Discriminator Loss: 0.330166 | Generator Loss: 1.357219
# 5/5 [==============================] - 3s 517ms/step
# Epoch: 1443 | Discriminator Loss: 0.325131 | Generator Loss: 1.672911
# 5/5 [==============================] - 3s 523ms/step
# Epoch: 1444 | Discriminator Loss: 0.341072 | Generator Loss: 1.625998
# 5/5 [==============================] - 3s 518ms/step
# Epoch: 1445 | Discriminator Loss: 0.330266 | Generator Loss: 1.455134
# 5/5 [==============================] - 3s 525ms/step
# Epoch: 1446 | Discriminator Loss: 0.339082 | Generator Loss: 1.387750
# 5/5 [==============================] - 3s 522ms/step
# Epoch: 1447 | Discriminator Loss: 0.310034 | Generator Loss: 1.375416
# 5/5 [==============================] - 3s 522ms/step
# Epoch: 1448 | Discriminator Loss: 0.328957 | Generator Loss: 1.564325
# 5/5 [==============================] - 3s 520ms/step
# Epoch: 1449 | Discriminator Loss: 0.321886 | Generator Loss: 1.310571
# 5/5 [==============================] - 3s 517ms/step
# Epoch: 1450 | Discriminator Loss: 0.332031 | Generator Loss: 1.223558
# 5/5 [==============================] - 3s 525ms/step
# Epoch: 1451 | Discriminator Loss: 0.348739 | Generator Loss: 1.045999
# 5/5 [==============================] - 3s 519ms/step
# Epoch: 1452 | Discriminator Loss: 0.341210 | Generator Loss: 1.062218
# 5/5 [==============================] - 3s 520ms/step
# Epoch: 1453 | Discriminator Loss: 0.349525 | Generator Loss: 1.307141
# 5/5 [==============================] - 3s 525ms/step
# Epoch: 1454 | Discriminator Loss: 0.338969 | Generator Loss: 1.522752
# 5/5 [==============================] - 3s 522ms/step
# Epoch: 1455 | Discriminator Loss: 0.347759 | Generator Loss: 1.462268
# 5/5 [==============================] - 3s 522ms/step
# Epoch: 1456 | Discriminator Loss: 0.345880 | Generator Loss: 1.475354
# 5/5 [==============================] - 3s 515ms/step
# Epoch: 1457 | Discriminator Loss: 0.332812 | Generator Loss: 1.448396
# 5/5 [==============================] - 3s 522ms/step
# Epoch: 1458 | Discriminator Loss: 0.349135 | Generator Loss: 1.356531
# 5/5 [==============================] - 3s 521ms/step
# Epoch: 1459 | Discriminator Loss: 0.342470 | Generator Loss: 1.371354
# 5/5 [==============================] - 3s 523ms/step
# Epoch: 1460 | Discriminator Loss: 0.355657 | Generator Loss: 1.552577
# 5/5 [==============================] - 3s 525ms/step
# Epoch: 1461 | Discriminator Loss: 0.367235 | Generator Loss: 1.615885
# 5/5 [==============================] - 3s 513ms/step
# Epoch: 1462 | Discriminator Loss: 0.334559 | Generator Loss: 1.668141
# 5/5 [==============================] - 3s 526ms/step
# Epoch: 1463 | Discriminator Loss: 0.353161 | Generator Loss: 1.367426
# 5/5 [==============================] - 3s 516ms/step
# Epoch: 1464 | Discriminator Loss: 0.345463 | Generator Loss: 1.274989
# 5/5 [==============================] - 3s 513ms/step
# Epoch: 1465 | Discriminator Loss: 0.350085 | Generator Loss: 1.170293
# 5/5 [==============================] - 3s 523ms/step
# Epoch: 1466 | Discriminator Loss: 0.329361 | Generator Loss: 1.041309
# 5/5 [==============================] - 3s 518ms/step
# Epoch: 1467 | Discriminator Loss: 0.344628 | Generator Loss: 1.129000
# 5/5 [==============================] - 3s 520ms/step
# Epoch: 1468 | Discriminator Loss: 0.325631 | Generator Loss: 1.140199
# 5/5 [==============================] - 3s 521ms/step
# Epoch: 1469 | Discriminator Loss: 0.329527 | Generator Loss: 1.125032
# 5/5 [==============================] - 3s 520ms/step
# Epoch: 1470 | Discriminator Loss: 0.325209 | Generator Loss: 1.086486
# 5/5 [==============================] - 3s 521ms/step
# Epoch: 1471 | Discriminator Loss: 0.347529 | Generator Loss: 1.342214
# 5/5 [==============================] - 3s 522ms/step
# Epoch: 1472 | Discriminator Loss: 0.346235 | Generator Loss: 1.295042
# 5/5 [==============================] - 3s 517ms/step
# Epoch: 1473 | Discriminator Loss: 0.341014 | Generator Loss: 1.146406
# 5/5 [==============================] - 3s 524ms/step
# Epoch: 1474 | Discriminator Loss: 0.328495 | Generator Loss: 0.874193
# 5/5 [==============================] - 3s 515ms/step
# Epoch: 1475 | Discriminator Loss: 0.308899 | Generator Loss: 0.810902
# 5/5 [==============================] - 3s 516ms/step
# Epoch: 1476 | Discriminator Loss: 0.319622 | Generator Loss: 0.833270
# 5/5 [==============================] - 3s 525ms/step
# Epoch: 1477 | Discriminator Loss: 0.315901 | Generator Loss: 0.915488
# 5/5 [==============================] - 3s 518ms/step
# Epoch: 1478 | Discriminator Loss: 0.330222 | Generator Loss: 1.166813
# 5/5 [==============================] - 3s 522ms/step
# Epoch: 1479 | Discriminator Loss: 0.327520 | Generator Loss: 0.940589
# 5/5 [==============================] - 3s 521ms/step
# Epoch: 1480 | Discriminator Loss: 0.340926 | Generator Loss: 0.916293
# 5/5 [==============================] - 3s 512ms/step
# Epoch: 1481 | Discriminator Loss: 0.337815 | Generator Loss: 0.810489
# 5/5 [==============================] - 3s 523ms/step
# Epoch: 1482 | Discriminator Loss: 0.341503 | Generator Loss: 0.808177
# 5/5 [==============================] - 3s 522ms/step
# Epoch: 1483 | Discriminator Loss: 0.362527 | Generator Loss: 0.940610
# 5/5 [==============================] - 3s 523ms/step
# Epoch: 1484 | Discriminator Loss: 0.337642 | Generator Loss: 1.407438
# 5/5 [==============================] - 3s 521ms/step
# Epoch: 1485 | Discriminator Loss: 0.365758 | Generator Loss: 1.585880
# 5/5 [==============================] - 3s 520ms/step
# Epoch: 1486 | Discriminator Loss: 0.338484 | Generator Loss: 1.232926
# 5/5 [==============================] - 3s 525ms/step
# Epoch: 1487 | Discriminator Loss: 0.338235 | Generator Loss: 1.292963
# 5/5 [==============================] - 3s 518ms/step
# Epoch: 1488 | Discriminator Loss: 0.326630 | Generator Loss: 1.414288
# 5/5 [==============================] - 3s 523ms/step
# Epoch: 1489 | Discriminator Loss: 0.334869 | Generator Loss: 1.546086
# 5/5 [==============================] - 3s 515ms/step
# Epoch: 1490 | Discriminator Loss: 0.349760 | Generator Loss: 1.741688
# 5/5 [==============================] - 3s 514ms/step
# Epoch: 1491 | Discriminator Loss: 0.351335 | Generator Loss: 1.324356
# 5/5 [==============================] - 3s 527ms/step
# Epoch: 1492 | Discriminator Loss: 0.346998 | Generator Loss: 1.428152
# 5/5 [==============================] - 3s 517ms/step
# Epoch: 1493 | Discriminator Loss: 0.346319 | Generator Loss: 1.203141
# 5/5 [==============================] - 3s 523ms/step
# Epoch: 1494 | Discriminator Loss: 0.323160 | Generator Loss: 1.058668
# 5/5 [==============================] - 3s 524ms/step
# Epoch: 1495 | Discriminator Loss: 0.352762 | Generator Loss: 0.991037
# 5/5 [==============================] - 3s 526ms/step
# Epoch: 1496 | Discriminator Loss: 0.350139 | Generator Loss: 0.978126
# 5/5 [==============================] - 3s 518ms/step
# Epoch: 1497 | Discriminator Loss: 0.392618 | Generator Loss: 1.713969
# 5/5 [==============================] - 3s 520ms/step
# Epoch: 1498 | Discriminator Loss: 0.316091 | Generator Loss: 1.366105
# 5/5 [==============================] - 3s 522ms/step
# Epoch: 1499 | Discriminator Loss: 0.343259 | Generator Loss: 0.665574
# 5/5 [==============================] - 3s 515ms/step
# Epoch: 1500 | Discriminator Loss: 0.318168 | Generator Loss: 0.503839
# 5/5 [==============================] - 3s 526ms/step
# Epoch: 1501 | Discriminator Loss: 0.328944 | Generator Loss: 0.486257
# 5/5 [==============================] - 3s 519ms/step
# Epoch: 1502 | Discriminator Loss: 0.344524 | Generator Loss: 0.480572
# 5/5 [==============================] - 3s 524ms/step
# Epoch: 1503 | Discriminator Loss: 0.335222 | Generator Loss: 0.538836
# 5/5 [==============================] - 3s 520ms/step
# Epoch: 1504 | Discriminator Loss: 0.329193 | Generator Loss: 0.485901
# 5/5 [==============================] - 3s 519ms/step
# Epoch: 1505 | Discriminator Loss: 0.313056 | Generator Loss: 0.502361
# 5/5 [==============================] - 3s 522ms/step
# Epoch: 1506 | Discriminator Loss: 0.317989 | Generator Loss: 0.520968
# 5/5 [==============================] - 3s 516ms/step
# Epoch: 1507 | Discriminator Loss: 0.329599 | Generator Loss: 0.508732
# 5/5 [==============================] - 3s 525ms/step
# Epoch: 1508 | Discriminator Loss: 0.306927 | Generator Loss: 0.516771
# 5/5 [==============================] - 3s 520ms/step
# Epoch: 1509 | Discriminator Loss: 0.328097 | Generator Loss: 0.639031
# 5/5 [==============================] - 3s 523ms/step
# Epoch: 1510 | Discriminator Loss: 0.325045 | Generator Loss: 0.783608
# 5/5 [==============================] - 3s 522ms/step
# Epoch: 1511 | Discriminator Loss: 0.332785 | Generator Loss: 1.141611
# 5/5 [==============================] - 3s 525ms/step
# Epoch: 1512 | Discriminator Loss: 0.330539 | Generator Loss: 1.492230
# 5/5 [==============================] - 3s 521ms/step
# Epoch: 1513 | Discriminator Loss: 0.318275 | Generator Loss: 1.856880
# 5/5 [==============================] - 3s 519ms/step
# Epoch: 1514 | Discriminator Loss: 0.328544 | Generator Loss: 1.653987
# 5/5 [==============================] - 3s 523ms/step
# Epoch: 1515 | Discriminator Loss: 0.324923 | Generator Loss: 1.266770
# 5/5 [==============================] - 3s 518ms/step
# Epoch: 1516 | Discriminator Loss: 0.324865 | Generator Loss: 1.069196
# 5/5 [==============================] - 3s 516ms/step
# Epoch: 1517 | Discriminator Loss: 0.319083 | Generator Loss: 0.958537
# 5/5 [==============================] - 3s 526ms/step
# Epoch: 1518 | Discriminator Loss: 0.330009 | Generator Loss: 0.847329
# 5/5 [==============================] - 3s 517ms/step
# Epoch: 1519 | Discriminator Loss: 0.341827 | Generator Loss: 0.695582
# 5/5 [==============================] - 3s 525ms/step
# Epoch: 1520 | Discriminator Loss: 0.330501 | Generator Loss: 0.739855
# 5/5 [==============================] - 3s 520ms/step
# Epoch: 1521 | Discriminator Loss: 0.348846 | Generator Loss: 0.835623
# 5/5 [==============================] - 3s 513ms/step
# Epoch: 1522 | Discriminator Loss: 0.338771 | Generator Loss: 0.856495
# 5/5 [==============================] - 3s 526ms/step
# Epoch: 1523 | Discriminator Loss: 0.327345 | Generator Loss: 0.766422
# 5/5 [==============================] - 3s 517ms/step
# Epoch: 1524 | Discriminator Loss: 0.345636 | Generator Loss: 0.628187
# 5/5 [==============================] - 3s 518ms/step
# Epoch: 1525 | Discriminator Loss: 0.324433 | Generator Loss: 0.602264
# 5/5 [==============================] - 3s 522ms/step
# Epoch: 1526 | Discriminator Loss: 0.321049 | Generator Loss: 0.718551
# 5/5 [==============================] - 3s 518ms/step
# Epoch: 1527 | Discriminator Loss: 0.332512 | Generator Loss: 1.049333
# 5/5 [==============================] - 3s 520ms/step
# Epoch: 1528 | Discriminator Loss: 0.341680 | Generator Loss: 1.314566
# 5/5 [==============================] - 3s 521ms/step
# Epoch: 1529 | Discriminator Loss: 0.319134 | Generator Loss: 1.546910
# 2/5 [===========>..................] - ETA: 1s
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-45-534b8d022857> in <module>()
# ----> 1 all_disc_loss_mod,all_gen_loss_mod = gan_training_loop_mod()
#
# <ipython-input-44-33768d236426> in gan_training_loop_mod(intervals)
#      22               #generate imgs and
#      23             #print(noise_samples)
# ---> 24             generated_imgs = generator.predict(noise_samples)
#      25
#      26             labels_real = smooth_real_labels(np.ones((BATCH_SIZE,), dtype=int))
#
# /usr/local/lib/python3.6/dist-packages/keras/engine/training.py in predict(self, x, batch_size, verbose, steps, callbacks, max_queue_size, workers, use_multiprocessing)
#    1460                                             verbose=verbose,
#    1461                                             steps=steps,
# -> 1462                                             callbacks=callbacks)
#    1463
#    1464     def train_on_batch(self, x, y,
#
# /usr/local/lib/python3.6/dist-packages/keras/engine/training_arrays.py in predict_loop(model, f, ins, batch_size, verbose, steps, callbacks)
#     322             batch_logs = {'batch': batch_index, 'size': len(batch_ids)}
#     323             callbacks._call_batch_hook('predict', 'begin', batch_index, batch_logs)
# --> 324             batch_outs = f(ins_batch)
#     325             batch_outs = to_list(batch_outs)
#     326             if batch_index == 0:
#
# /tensorflow-1.15.2/python3.6/tensorflow_core/python/keras/backend.py in __call__(self, inputs)
#    3474
#    3475     fetched = self._callable_fn(*array_vals,
# -> 3476                                 run_metadata=self.run_metadata)
#    3477     self._call_fetch_callbacks(fetched[-len(self._fetches):])
#    3478     output_structure = nest.pack_sequence_as(
#
# /tensorflow-1.15.2/python3.6/tensorflow_core/python/client/session.py in __call__(self, *args, **kwargs)
#    1470         ret = tf_session.TF_SessionRunCallable(self._session._session,
#    1471                                                self._handle, args,
# -> 1472                                                run_metadata_ptr)
#    1473         if run_metadata:
#    1474           proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# KeyboardInterrupt:

# %%
#mod8 - flipping + smoothing gen, smoothing both for disc, lr 0.0001 disc, 0.001 gen
plot_loss(all_gen_loss_mod,all_disc_loss_mod)

# %% [markdown]
# ####Plot Analysis

# %% [markdown]
# <li> The stable gan has much less variation in generator loss, which means it is now able to fool the discriminator much better.
# <li> The discriminator loss jumps up frequently, showing that the generator was able to fool it more this time.
# <li> The generator loss is also much lower and closer to the discriminator loss

# %%
generator_mod = build_generator_mod()
generator_mod.load_weights('/content/drive/My Drive/DLAS5/generator_mod8')

# %%
for i in range(1,5):
  noise = sample_noise_mod()
  grid = generator_mod.predict(noise)
  save_samples(grid,i,save_at='final_mod8')

# %% [markdown]
# ### Analysis
# Repeat the above analysis and mention changes you observed in terms of training and quality of fake images <br>
#
#  The images generated from the unstable GAN lacked quality and variation whereas the stable GAN produced much better results after the following optimizations were applied:
# *   Using a learning rate of 0.0001 for the discriminator and 0.001 for the generator.
# *   Smoothing the labels passed to the discriminator and flipping the labels of the generator with a 5% probability. Since the unstable gan had little to no variation(Mode Collapse), flipping the labels helped the generator learn more diverse features
# *  Normalizing the training images helped the gan learn features much more clearly than before.
#
# These modifications in the training loop resulted in the generator being able to produce recognizable emojis with diverse features and low level of duplication. The optimizations also decreased the generator loss and variation by a significant margin. No failure modes were encountered in this training

# %%
#interpolating samples with vector math
noise1 = sample_noise_mod()
grid1 = generator_mod.predict(noise)
save_samples(grid1,1,save_at='vector_gen')

noise2 = sample_noise_mod()
grid2 = generator_mod.predict(noise2)
save_samples(grid2,2,save_at='vector_gen')

noise3 = sample_noise_mod()
grid3 = generator_mod.predict(noise3)
save_samples(grid3,3,save_at='vector_gen')

# %%
grid4 = generator_mod.predict(noise1 - noise2 + noise3)
save_samples(grid4,4,save_at='vector_gen')

# %% [markdown]
# The interpolation unfortunately does not produce results as expected. This is perhaps because the samples do not have very clearly defined features.

# %% [markdown]
# ## BONUS - 10%
# The current training set was a subset of the actual emojis dataset. In the filtering process, most inanimate objects were removed and the focus was on front-facing emojis. Train the model over the full dataset or a subset of your choice and repeat the above analysis
